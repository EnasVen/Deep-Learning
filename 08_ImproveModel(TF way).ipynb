# %% [markdown]
# # 平均損失函數
# reduce_mean(loss) 可以讓每一個batch訓練後output出當前batch的loss

# %%
import numpy as np
import tensorflow as tf
tf.compat.v1.reset_default_graph()
class MNISTLoader():
    def __init__(self):
        mnist = tf.keras.datasets.mnist
        (self.train_data, self.train_label), (self.test_data, self.test_label) = mnist.load_data()

        self.train_data = np.expand_dims(self.train_data.astype(np.float32) / 255.0, axis=-1)      # [60000, 28, 28, 1]
        self.test_data = np.expand_dims(self.test_data.astype(np.float32) / 255.0, axis=-1)        # [10000, 28, 28, 1]
        self.train_label = self.train_label.astype(np.int32)    # [60000]
        self.test_label = self.test_label.astype(np.int32)      # [10000]
        self.num_train_data, self.num_test_data = self.train_data.shape[0], self.test_data.shape[0]

    def get_batch(self, batch_size):

        index = np.random.randint(0, self.num_train_data, batch_size)
        return self.train_data[index, :], self.train_label[index]
    
class MLP(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.flatten = tf.keras.layers.Flatten()    
        self.dense1 = tf.keras.layers.Dense(units=100, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(units=10)

    def call(self, inputs):         # [batch_size, 28, 28, 1]
        x = self.flatten(inputs)    # [batch_size, 784]
        x = self.dense1(x)          # [batch_size, 100]
        x = self.dense2(x)          # [batch_size, 10]
        output = tf.nn.softmax(x)
        return output

num_epochs = 5
batch_size = 5
learning_rate = 0.001

model = MLP()
data_loader = MNISTLoader()

num_batches = int(data_loader.num_train_data // batch_size * num_epochs)

X, y = data_loader.get_batch(batch_size)
with tf.GradientTape() as tape:
    y_pred = model(X)
    loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=y, y_pred=y_pred)
    # 計算當前 batch loss
    loss = tf.reduce_mean(loss)
    print(loss)
# Out:
# tf.Tensor(2.621033, shape=(), dtype=float32)

# %% [markdown]
# # 優化神經網路(TensorFlow版本)

# %%
import tensorflow as tf
import numpy as np
class MNISTLoader():
    def __init__(self):
        mnist = tf.keras.datasets.mnist
        (self.train_data, self.train_label), (self.test_data, self.test_label) = mnist.load_data()

        self.train_data = np.expand_dims(self.train_data.astype(np.float32) / 255.0, axis=-1)      # [60000, 28, 28, 1]
        self.test_data = np.expand_dims(self.test_data.astype(np.float32) / 255.0, axis=-1)        # [10000, 28, 28, 1]
        self.train_label = self.train_label.astype(np.int32)    # [60000]
        self.test_label = self.test_label.astype(np.int32)      # [10000]
        self.num_train_data, self.num_test_data = self.train_data.shape[0], self.test_data.shape[0]

    def get_batch(self, batch_size):

        index = np.random.randint(0, self.num_train_data, batch_size)
        return self.train_data[index, :], self.train_label[index]
    
class MLP(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.flatten = tf.keras.layers.Flatten()    
        self.dense1 = tf.keras.layers.Dense(units=100, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(units=10)

    def call(self, inputs):         # [batch_size, 28, 28, 1]
        x = self.flatten(inputs)    # [batch_size, 784]
        x = self.dense1(x)          # [batch_size, 100]
        x = self.dense2(x)          # [batch_size, 10]
        output = tf.nn.softmax(x)
        return output

num_epochs = 5
batch_size = 50
learning_rate = 0.001

model = MLP()
data_loader = MNISTLoader()
#optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
#optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)

# num_batches = int(data_loader.num_train_data // batch_size * num_epochs)
num_batches = int(np.ceil(data_loader.num_train_data // batch_size)) * num_epochs
print(model.variables)  # []
for batch_index in range(num_batches):
    X, y = data_loader.get_batch(batch_size)
    with tf.GradientTape() as tape:
        y_pred = model(X)
        loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=y, y_pred=y_pred)
        loss = tf.reduce_mean(loss)
        print("batch %d: loss %f" % (batch_index, loss.numpy()))
    grads = tape.gradient(loss, model.variables)
    optimizer.apply_gradients(grads_and_vars=zip(grads, model.variables))
# Out:
# []
# batch 0: loss 2.320936
# batch 1: loss 2.040167
# batch 2: loss 2.087241
# batch 3: loss 1.757956
# batch 4: loss 1.886571
# batch 5: loss 1.735484
# batch 6: loss 1.527186
# batch 7: loss 1.568506
# batch 8: loss 1.441880
# batch 9: loss 1.411643
# batch 10: loss 1.360865
# batch 11: loss 1.219160
# batch 12: loss 1.093266
# batch 13: loss 1.200287
# batch 14: loss 1.055199
# batch 15: loss 0.987168
# batch 16: loss 1.034901
# batch 17: loss 0.962319
# batch 18: loss 0.913380
# batch 19: loss 0.955973
# batch 20: loss 0.895367
# batch 21: loss 0.938127
# batch 22: loss 0.855748
# batch 23: loss 0.908024
# batch 24: loss 0.766844
# batch 25: loss 0.959602
# batch 26: loss 0.920797
# batch 27: loss 0.659319
# batch 28: loss 0.790139
# batch 29: loss 0.776857
# batch 30: loss 0.819875
# batch 31: loss 0.811049
# batch 32: loss 0.860959
# batch 33: loss 0.794132
# batch 34: loss 0.797881
# batch 35: loss 0.787934
# batch 36: loss 0.627918
# batch 37: loss 0.497544
# batch 38: loss 0.550038
# batch 39: loss 0.708925
# batch 40: loss 0.681207
# batch 41: loss 0.671071
# batch 42: loss 0.722752
# batch 43: loss 0.838167
# batch 44: loss 0.639787
# batch 45: loss 0.733690
# batch 46: loss 0.790912
# batch 47: loss 0.583474
# batch 48: loss 0.478685
# batch 49: loss 0.523133
# batch 50: loss 0.667276
# batch 51: loss 0.561672
# batch 52: loss 0.552179
# batch 53: loss 0.596858
# batch 54: loss 0.447350
# batch 55: loss 0.604839
# batch 56: loss 0.533281
# batch 57: loss 0.442583
# batch 58: loss 0.430611
# batch 59: loss 0.496998
# batch 60: loss 0.432296
# batch 61: loss 0.464553
# batch 62: loss 0.391959
# batch 63: loss 0.459111
# batch 64: loss 0.400538
# batch 65: loss 0.558523
# batch 66: loss 0.499373
# batch 67: loss 0.529297
# batch 68: loss 0.417060
# batch 69: loss 0.491256
# batch 70: loss 0.312424
# batch 71: loss 0.496671
# batch 72: loss 0.352389
# batch 73: loss 0.414169
# batch 74: loss 0.536000
# batch 75: loss 0.441005
# batch 76: loss 0.566332
# batch 77: loss 0.435500
# batch 78: loss 0.620670
# batch 79: loss 0.468936
# batch 80: loss 0.417758
# batch 81: loss 0.330011
# batch 82: loss 0.317712
# batch 83: loss 0.337000
# batch 84: loss 0.475720
# batch 85: loss 0.589674
# batch 86: loss 0.483063
# batch 87: loss 0.336499
# batch 88: loss 0.385649
# batch 89: loss 0.370410
# batch 90: loss 0.288015
# batch 91: loss 0.495308
# batch 92: loss 0.309479
# batch 93: loss 0.504500
# batch 94: loss 0.480234
# batch 95: loss 0.407690
# batch 96: loss 0.417949
# batch 97: loss 0.587456
# batch 98: loss 0.588548
# batch 99: loss 0.373031
# batch 100: loss 0.500662
# batch 101: loss 0.426526
# batch 102: loss 0.557906
# batch 103: loss 0.384437
# batch 104: loss 0.337075
# batch 105: loss 0.557827
# batch 106: loss 0.588590
# batch 107: loss 0.361041
# batch 108: loss 0.447336
# batch 109: loss 0.286711
# batch 110: loss 0.418752
# batch 111: loss 0.402347
# batch 112: loss 0.585431
# batch 113: loss 0.328611
# batch 114: loss 0.668754
# batch 115: loss 0.449421
# batch 116: loss 0.437363
# batch 117: loss 0.459438
# batch 118: loss 0.393115
# batch 119: loss 0.362667
# batch 120: loss 0.787967
# batch 121: loss 0.383286
# batch 122: loss 0.504815
# batch 123: loss 0.284018
# batch 124: loss 0.638550
# batch 125: loss 0.315257
# batch 126: loss 0.241843
# batch 127: loss 0.411283
# batch 128: loss 0.518904
# batch 129: loss 0.353866
# batch 130: loss 0.396903
# batch 131: loss 0.403192
# batch 132: loss 0.251608
# batch 133: loss 0.476802
# batch 134: loss 0.533902
# batch 135: loss 0.236783
# batch 136: loss 0.434778
# batch 137: loss 0.302499
# batch 138: loss 0.560837
# batch 139: loss 0.259789
# batch 140: loss 0.492476
# batch 141: loss 0.490900
# batch 142: loss 0.396470
# batch 143: loss 0.498481
# batch 144: loss 0.377896
# batch 145: loss 0.276961
# batch 146: loss 0.461178
# batch 147: loss 0.339017
# batch 148: loss 0.309781
# batch 149: loss 0.403054
# batch 150: loss 0.432322
# batch 151: loss 0.318111
# batch 152: loss 0.483207
# batch 153: loss 0.442006
# batch 154: loss 0.241704
# batch 155: loss 0.345753
# batch 156: loss 0.386725
# batch 157: loss 0.406130
# batch 158: loss 0.299907
# batch 159: loss 0.338923
# batch 160: loss 0.221331
# batch 161: loss 0.225646
# batch 162: loss 0.301707
# batch 163: loss 0.225766
# batch 164: loss 0.491595
# batch 165: loss 0.338230
# batch 166: loss 0.326568
# batch 167: loss 0.286177
# batch 168: loss 0.271282
# batch 169: loss 0.341560
# batch 170: loss 0.225284
# batch 171: loss 0.297455
# batch 172: loss 0.616256
# batch 173: loss 0.365992
# batch 174: loss 0.496326
# batch 175: loss 0.265869
# batch 176: loss 0.201889
# batch 177: loss 0.422211
# batch 178: loss 0.291612
# batch 179: loss 0.476023
# batch 180: loss 0.399251
# batch 181: loss 0.217500
# batch 182: loss 0.274560
# batch 183: loss 0.392762
# batch 184: loss 0.350742
# batch 185: loss 0.150102
# batch 186: loss 0.176344
# batch 187: loss 0.211526
# batch 188: loss 0.329631
# batch 189: loss 0.333165
# batch 190: loss 0.385468
# batch 191: loss 0.423836
# batch 192: loss 0.175581
# batch 193: loss 0.463574
# batch 194: loss 0.434354
# batch 195: loss 0.257566
# batch 196: loss 0.421732
# batch 197: loss 0.309818
# batch 198: loss 0.333094
# batch 199: loss 0.178709
# batch 200: loss 0.348417
# batch 201: loss 0.187400
# batch 202: loss 0.387411
# batch 203: loss 0.390744
# batch 204: loss 0.301823
# batch 205: loss 0.176406
# batch 206: loss 0.300899
# batch 207: loss 0.301184
# batch 208: loss 0.206121
# batch 209: loss 0.330091
# batch 210: loss 0.243545
# batch 211: loss 0.307119
# batch 212: loss 0.346811
# batch 213: loss 0.192411
# batch 214: loss 0.242723
# batch 215: loss 0.324666
# batch 216: loss 0.147378
# batch 217: loss 0.347125
# batch 218: loss 0.363652
# batch 219: loss 0.351228
# batch 220: loss 0.240552
# batch 221: loss 0.247781
# batch 222: loss 0.338769
# batch 223: loss 0.587326
# batch 224: loss 0.231475
# batch 225: loss 0.161243
# batch 226: loss 0.377169
# batch 227: loss 0.392615
# batch 228: loss 0.221182
# batch 229: loss 0.492745
# batch 230: loss 0.354517
# batch 231: loss 0.299952
# batch 232: loss 0.323041
# batch 233: loss 0.536931
# batch 234: loss 0.264584
# batch 235: loss 0.187224
# batch 236: loss 0.394338
# batch 237: loss 0.282699
# batch 238: loss 0.535454
# batch 239: loss 0.266879
# batch 240: loss 0.305053
# batch 241: loss 0.255269
# batch 242: loss 0.243480
# batch 243: loss 0.239419
# batch 244: loss 0.222411
# batch 245: loss 0.160841
# batch 246: loss 0.220315
# batch 247: loss 0.237518
# batch 248: loss 0.441018
# batch 249: loss 0.197134
# batch 250: loss 0.444880
# batch 251: loss 0.312773
# batch 252: loss 0.166339
# batch 253: loss 0.179255
# batch 254: loss 0.399793
# batch 255: loss 0.421774
# batch 256: loss 0.520397
# batch 257: loss 0.541998
# batch 258: loss 0.240258
# batch 259: loss 0.271437
# batch 260: loss 0.313192
# batch 261: loss 0.304644
# batch 262: loss 0.464507
# batch 263: loss 0.398563
# batch 264: loss 0.376262
# batch 265: loss 0.592757
# batch 266: loss 0.409925
# batch 267: loss 0.301641
# batch 268: loss 0.380220
# batch 269: loss 0.293800
# batch 270: loss 0.211948
# batch 271: loss 0.455360
# batch 272: loss 0.266161
# batch 273: loss 0.368750
# batch 274: loss 0.279737
# batch 275: loss 0.233299
# batch 276: loss 0.151132
# batch 277: loss 0.207087
# batch 278: loss 0.326867
# batch 279: loss 0.208794
# batch 280: loss 0.379382
# batch 281: loss 0.360438
# batch 282: loss 0.545844
# batch 283: loss 0.410064
# batch 284: loss 0.222292
# batch 285: loss 0.216897
# batch 286: loss 0.455899
# batch 287: loss 0.318595
# batch 288: loss 0.426676
# batch 289: loss 0.289566
# batch 290: loss 0.307276
# batch 291: loss 0.560095
# batch 292: loss 0.359361
# batch 293: loss 0.393806
# batch 294: loss 0.239662
# batch 295: loss 0.275622
# batch 296: loss 0.380905
# batch 297: loss 0.248794
# batch 298: loss 0.623743
# batch 299: loss 0.307638
# batch 300: loss 0.292681
# batch 301: loss 0.269403
# batch 302: loss 0.168912
# batch 303: loss 0.400446
# batch 304: loss 0.330130
# batch 305: loss 0.191831
# batch 306: loss 0.475057
# batch 307: loss 0.292296
# batch 308: loss 0.550125
# batch 309: loss 0.277213
# batch 310: loss 0.515759
# batch 311: loss 0.188703
# batch 312: loss 0.177132
# batch 313: loss 0.187588
# batch 314: loss 0.511740
# batch 315: loss 0.277266
# batch 316: loss 0.204771
# batch 317: loss 0.325735
# batch 318: loss 0.256093
# batch 319: loss 0.202184
# batch 320: loss 0.272580
# batch 321: loss 0.229371
# batch 322: loss 0.276998
# batch 323: loss 0.274067
# batch 324: loss 0.211303
# batch 325: loss 0.383017
# batch 326: loss 0.173983
# batch 327: loss 0.317714
# batch 328: loss 0.334648
# batch 329: loss 0.301112
# batch 330: loss 0.192117
# batch 331: loss 0.310975
# batch 332: loss 0.188690
# batch 333: loss 0.178119
# batch 334: loss 0.393664
# batch 335: loss 0.182012
# batch 336: loss 0.173172
# batch 337: loss 0.213785
# batch 338: loss 0.306078
# batch 339: loss 0.250535
# batch 340: loss 0.256554
# batch 341: loss 0.267370
# batch 342: loss 0.285779
# batch 343: loss 0.134406
# batch 344: loss 0.182665
# batch 345: loss 0.442290
# batch 346: loss 0.184755
# batch 347: loss 0.319488
# batch 348: loss 0.254903
# batch 349: loss 0.124323
# batch 350: loss 0.125758
# batch 351: loss 0.084837
# batch 352: loss 0.138554
# batch 353: loss 0.385712
# batch 354: loss 0.256381
# batch 355: loss 0.287896
# batch 356: loss 0.592767
# batch 357: loss 0.346109
# batch 358: loss 0.191716
# batch 359: loss 0.288078
# batch 360: loss 0.237936
# batch 361: loss 0.297739
# batch 362: loss 0.195718
# batch 363: loss 0.456681
# batch 364: loss 0.346591
# batch 365: loss 0.419656
# batch 366: loss 0.216614
# batch 367: loss 0.279764
# batch 368: loss 0.126894
# batch 369: loss 0.527574
# batch 370: loss 0.167437
# batch 371: loss 0.249926
# batch 372: loss 0.322458
# batch 373: loss 0.351234
# batch 374: loss 0.295047
# batch 375: loss 0.305937
# batch 376: loss 0.352207
# batch 377: loss 0.236255
# batch 378: loss 0.231335
# batch 379: loss 0.364923
# batch 380: loss 0.301864
# batch 381: loss 0.289627
# batch 382: loss 0.371116
# batch 383: loss 0.154876
# batch 384: loss 0.162159
# batch 385: loss 0.455879
# batch 386: loss 0.245274
# batch 387: loss 0.304666
# batch 388: loss 0.175215
# batch 389: loss 0.256653
# batch 390: loss 0.152306
# batch 391: loss 0.263013
# batch 392: loss 0.186424
# batch 393: loss 0.217653
# batch 394: loss 0.403954
# batch 395: loss 0.205675
# batch 396: loss 0.215201
# batch 397: loss 0.330063
# batch 398: loss 0.534955
# batch 399: loss 0.238884
# batch 400: loss 0.349323
# batch 401: loss 0.266322
# batch 402: loss 0.528441
# batch 403: loss 0.293387
# batch 404: loss 0.306849
# batch 405: loss 0.454281
# batch 406: loss 0.344513
# batch 407: loss 0.271546
# batch 408: loss 0.144995
# batch 409: loss 0.319565
# batch 410: loss 0.358367
# batch 411: loss 0.329058
# batch 412: loss 0.330117
# batch 413: loss 0.302586
# batch 414: loss 0.215179
# batch 415: loss 0.243772
# batch 416: loss 0.081500
# batch 417: loss 0.188877
# batch 418: loss 0.449506
# batch 419: loss 0.180884
# batch 420: loss 0.141581
# batch 421: loss 0.332782
# batch 422: loss 0.165962
# batch 423: loss 0.151505
# batch 424: loss 0.281947
# batch 425: loss 0.322551
# batch 426: loss 0.322612
# batch 427: loss 0.263207
# batch 428: loss 0.403821
# batch 429: loss 0.187838
# batch 430: loss 0.233509
# batch 431: loss 0.072669
# batch 432: loss 0.643159
# batch 433: loss 0.462425
# batch 434: loss 0.304627
# batch 435: loss 0.536045
# batch 436: loss 0.485357
# batch 437: loss 0.148430
# batch 438: loss 0.227577
# batch 439: loss 0.209918
# batch 440: loss 0.225166
# batch 441: loss 0.303917
# batch 442: loss 0.350542
# batch 443: loss 0.167299
# batch 444: loss 0.176082
# batch 445: loss 0.334897
# batch 446: loss 0.174718
# batch 447: loss 0.159253
# batch 448: loss 0.212938
# batch 449: loss 0.086232
# batch 450: loss 0.272808
# batch 451: loss 0.455390
# batch 452: loss 0.399223
# batch 453: loss 0.113054
# batch 454: loss 0.364725
# batch 455: loss 0.139803
# batch 456: loss 0.337520
# batch 457: loss 0.177449
# batch 458: loss 0.165013
# batch 459: loss 0.332299
# batch 460: loss 0.145348
# batch 461: loss 0.255189
# batch 462: loss 0.081419
# batch 463: loss 0.505220
# batch 464: loss 0.455953
# batch 465: loss 0.215881
# batch 466: loss 0.192568
# batch 467: loss 0.204928
# batch 468: loss 0.298208
# batch 469: loss 0.182517
# batch 470: loss 0.292437
# batch 471: loss 0.253894
# batch 472: loss 0.402073
# batch 473: loss 0.359554
# batch 474: loss 0.416054
# batch 475: loss 0.271759
# batch 476: loss 0.186681
# batch 477: loss 0.093339
# batch 478: loss 0.254696
# batch 479: loss 0.306077
# batch 480: loss 0.239405
# batch 481: loss 0.172838
# batch 482: loss 0.261091
# batch 483: loss 0.255922
# batch 484: loss 0.406449
# batch 485: loss 0.411519
# batch 486: loss 0.130872
# batch 487: loss 0.205220
# batch 488: loss 0.305716
# batch 489: loss 0.205349
# batch 490: loss 0.103984
# batch 491: loss 0.211505
# batch 492: loss 0.170868
# batch 493: loss 0.303526
# batch 494: loss 0.223148
# batch 495: loss 0.292457
# batch 496: loss 0.222966
# batch 497: loss 0.076867
# batch 498: loss 0.123292
# batch 499: loss 0.228207
# batch 500: loss 0.240741
# batch 501: loss 0.282261
# batch 502: loss 0.288264
# batch 503: loss 0.376802
# batch 504: loss 0.143376
# batch 505: loss 0.339397
# batch 506: loss 0.220976
# batch 507: loss 0.178746
# batch 508: loss 0.220765
# batch 509: loss 0.079378
# batch 510: loss 0.276399
# batch 511: loss 0.241287
# batch 512: loss 0.327063
# batch 513: loss 0.132244
# batch 514: loss 0.210943
# batch 515: loss 0.479321
# batch 516: loss 0.211663
# batch 517: loss 0.185870
# batch 518: loss 0.373484
# batch 519: loss 0.202482
# batch 520: loss 0.156020
# batch 521: loss 0.214857
# batch 522: loss 0.229669
# batch 523: loss 0.274117
# batch 524: loss 0.216501
# batch 525: loss 0.423911
# batch 526: loss 0.257708
# batch 527: loss 0.335532
# batch 528: loss 0.168829
# batch 529: loss 0.259802
# batch 530: loss 0.216234
# batch 531: loss 0.380514
# batch 532: loss 0.193715
# batch 533: loss 0.117012
# batch 534: loss 0.142980
# batch 535: loss 0.442903
# batch 536: loss 0.223212
# batch 537: loss 0.431486
# batch 538: loss 0.197259
# batch 539: loss 0.118477
# batch 540: loss 0.188466
# batch 541: loss 0.371499
# batch 542: loss 0.267404
# batch 543: loss 0.290533
# batch 544: loss 0.256415
# batch 545: loss 0.123117
# batch 546: loss 0.100825
# batch 547: loss 0.464149
# batch 548: loss 0.284488
# batch 549: loss 0.169677
# batch 550: loss 0.180574
# batch 551: loss 0.361245
# batch 552: loss 0.275384
# batch 553: loss 0.191356
# batch 554: loss 0.335499
# batch 555: loss 0.126352
# batch 556: loss 0.127715
# batch 557: loss 0.106450
# batch 558: loss 0.411790
# batch 559: loss 0.236507
# batch 560: loss 0.316538
# batch 561: loss 0.287478
# batch 562: loss 0.270554
# batch 563: loss 0.111804
# batch 564: loss 0.340077
# batch 565: loss 0.232120
# batch 566: loss 0.177186
# batch 567: loss 0.328300
# batch 568: loss 0.126984
# batch 569: loss 0.123843
# batch 570: loss 0.075145
# batch 571: loss 0.168111
# batch 572: loss 0.084580
# batch 573: loss 0.123482
# batch 574: loss 0.354963
# batch 575: loss 0.353971
# batch 576: loss 0.148737
# batch 577: loss 0.285707
# batch 578: loss 0.330864
# batch 579: loss 0.115669
# batch 580: loss 0.309207
# batch 581: loss 0.463791
# batch 582: loss 0.183034
# batch 583: loss 0.203145
# batch 584: loss 0.397749
# batch 585: loss 0.309335
# batch 586: loss 0.127028
# batch 587: loss 0.172855
# batch 588: loss 0.227694
# batch 589: loss 0.152244
# batch 590: loss 0.195906
# batch 591: loss 0.077067
# batch 592: loss 0.369177
# batch 593: loss 0.337935
# batch 594: loss 0.113208
# batch 595: loss 0.268131
# batch 596: loss 0.559691
# batch 597: loss 0.148042
# batch 598: loss 0.140066
# batch 599: loss 0.134554
# batch 600: loss 0.209449
# batch 601: loss 0.260931
# batch 602: loss 0.262724
# batch 603: loss 0.210498
# batch 604: loss 0.120157
# batch 605: loss 0.205506
# batch 606: loss 0.222778
# batch 607: loss 0.223283
# batch 608: loss 0.156786
# batch 609: loss 0.217673
# batch 610: loss 0.202321
# batch 611: loss 0.290419
# batch 612: loss 0.421099
# batch 613: loss 0.094808
# batch 614: loss 0.111957
# batch 615: loss 0.225619
# batch 616: loss 0.354156
# batch 617: loss 0.222629
# batch 618: loss 0.155963
# batch 619: loss 0.393740
# batch 620: loss 0.300092
# batch 621: loss 0.142237
# batch 622: loss 0.253648
# batch 623: loss 0.129928
# batch 624: loss 0.247898
# batch 625: loss 0.189493
# batch 626: loss 0.156778
# batch 627: loss 0.365981
# batch 628: loss 0.144039
# batch 629: loss 0.219929
# batch 630: loss 0.402314
# batch 631: loss 0.493728
# batch 632: loss 0.174255
# batch 633: loss 0.230077
# batch 634: loss 0.085629
# batch 635: loss 0.109600
# batch 636: loss 0.099761
# batch 637: loss 0.191475
# batch 638: loss 0.176081
# batch 639: loss 0.306426
# batch 640: loss 0.289337
# batch 641: loss 0.122235
# batch 642: loss 0.226872
# batch 643: loss 0.212798
# batch 644: loss 0.142673
# batch 645: loss 0.280055
# batch 646: loss 0.181329
# batch 647: loss 0.287492
# batch 648: loss 0.438266
# batch 649: loss 0.138746
# batch 650: loss 0.208533
# batch 651: loss 0.189637
# batch 652: loss 0.287940
# batch 653: loss 0.224316
# batch 654: loss 0.213534
# batch 655: loss 0.290057
# batch 656: loss 0.208313
# batch 657: loss 0.244580
# batch 658: loss 0.124352
# batch 659: loss 0.473474
# batch 660: loss 0.181745
# batch 661: loss 0.248597
# batch 662: loss 0.261377
# batch 663: loss 0.150946
# batch 664: loss 0.127410
# batch 665: loss 0.261311
# batch 666: loss 0.163585
# batch 667: loss 0.191468
# batch 668: loss 0.380100
# batch 669: loss 0.243034
# batch 670: loss 0.327521
# batch 671: loss 0.077448
# batch 672: loss 0.074959
# batch 673: loss 0.143720
# batch 674: loss 0.213359
# batch 675: loss 0.048653
# batch 676: loss 0.164930
# batch 677: loss 0.165594
# batch 678: loss 0.090520
# batch 679: loss 0.134002
# batch 680: loss 0.153736
# batch 681: loss 0.130537
# batch 682: loss 0.120348
# batch 683: loss 0.144836
# batch 684: loss 0.141832
# batch 685: loss 0.252418
# batch 686: loss 0.165446
# batch 687: loss 0.198727
# batch 688: loss 0.258560
# batch 689: loss 0.375070
# batch 690: loss 0.084238
# batch 691: loss 0.091868
# batch 692: loss 0.217913
# batch 693: loss 0.088863
# batch 694: loss 0.370628
# batch 695: loss 0.379314
# batch 696: loss 0.196742
# batch 697: loss 0.248198
# batch 698: loss 0.129157
# batch 699: loss 0.198715
# batch 700: loss 0.305378
# batch 701: loss 0.253635
# batch 702: loss 0.138628
# batch 703: loss 0.234693
# batch 704: loss 0.140639
# batch 705: loss 0.293959
# batch 706: loss 0.148352
# batch 707: loss 0.180872
# batch 708: loss 0.116072
# batch 709: loss 0.109790
# batch 710: loss 0.227721
# batch 711: loss 0.321411
# batch 712: loss 0.111580
# batch 713: loss 0.221190
# batch 714: loss 0.310750
# batch 715: loss 0.574431
# batch 716: loss 0.187040
# batch 717: loss 0.317550
# batch 718: loss 0.275756
# batch 719: loss 0.226347
# batch 720: loss 0.210430
# batch 721: loss 0.209096
# batch 722: loss 0.261851
# batch 723: loss 0.211138
# batch 724: loss 0.222202
# batch 725: loss 0.141594
# batch 726: loss 0.394537
# batch 727: loss 0.224996
# batch 728: loss 0.176178
# batch 729: loss 0.187781
# batch 730: loss 0.151130
# batch 731: loss 0.196070
# batch 732: loss 0.185019
# batch 733: loss 0.143075
# batch 734: loss 0.146772
# batch 735: loss 0.095376
# batch 736: loss 0.093164
# batch 737: loss 0.236451
# batch 738: loss 0.205560
# batch 739: loss 0.078525
# batch 740: loss 0.224052
# batch 741: loss 0.172438
# batch 742: loss 0.476509
# batch 743: loss 0.195033
# batch 744: loss 0.194511
# batch 745: loss 0.143063
# batch 746: loss 0.153849
# batch 747: loss 0.272005
# batch 748: loss 0.307151
# batch 749: loss 0.189743
# batch 750: loss 0.094428
# batch 751: loss 0.195260
# batch 752: loss 0.384941
# batch 753: loss 0.166835
# batch 754: loss 0.185082
# batch 755: loss 0.253755
# batch 756: loss 0.236744
# batch 757: loss 0.376734
# batch 758: loss 0.314369
# batch 759: loss 0.079750
# batch 760: loss 0.225348
# batch 761: loss 0.268385
# batch 762: loss 0.318865
# batch 763: loss 0.203878
# batch 764: loss 0.197139
# batch 765: loss 0.086235
# batch 766: loss 0.488643
# batch 767: loss 0.234838
# batch 768: loss 0.083979
# batch 769: loss 0.107188
# batch 770: loss 0.179974
# batch 771: loss 0.196597
# batch 772: loss 0.310565
# batch 773: loss 0.137476
# batch 774: loss 0.216171
# batch 775: loss 0.170693
# batch 776: loss 0.357111
# batch 777: loss 0.357935
# batch 778: loss 0.319445
# batch 779: loss 0.095083
# batch 780: loss 0.055321
# batch 781: loss 0.192642
# batch 782: loss 0.231307
# batch 783: loss 0.141671
# batch 784: loss 0.178207
# batch 785: loss 0.154208
# batch 786: loss 0.106593
# batch 787: loss 0.161080
# batch 788: loss 0.183241
# batch 789: loss 0.222750
# batch 790: loss 0.115152
# batch 791: loss 0.252490
# batch 792: loss 0.159873
# batch 793: loss 0.390003
# batch 794: loss 0.146459
# batch 795: loss 0.184051
# batch 796: loss 0.351115
# batch 797: loss 0.208010
# batch 798: loss 0.185751
# batch 799: loss 0.130112
# batch 800: loss 0.108540
# batch 801: loss 0.139434
# batch 802: loss 0.231707
# batch 803: loss 0.154198
# batch 804: loss 0.087652
# batch 805: loss 0.146261
# batch 806: loss 0.277443
# batch 807: loss 0.150274
# batch 808: loss 0.121478
# batch 809: loss 0.375055
# batch 810: loss 0.351487
# batch 811: loss 0.218655
# batch 812: loss 0.232867
# batch 813: loss 0.209782
# batch 814: loss 0.181373
# batch 815: loss 0.498902
# batch 816: loss 0.134624
# batch 817: loss 0.179507
# batch 818: loss 0.153372
# batch 819: loss 0.155974
# batch 820: loss 0.202629
# batch 821: loss 0.219905
# batch 822: loss 0.159695
# batch 823: loss 0.381755
# batch 824: loss 0.141776
# batch 825: loss 0.144392
# batch 826: loss 0.096631
# batch 827: loss 0.216046
# batch 828: loss 0.164176
# batch 829: loss 0.128154
# batch 830: loss 0.229978
# batch 831: loss 0.108486
# batch 832: loss 0.109744
# batch 833: loss 0.239559
# batch 834: loss 0.169673
# batch 835: loss 0.110491
# batch 836: loss 0.188871
# batch 837: loss 0.235846
# batch 838: loss 0.270813
# batch 839: loss 0.145453
# batch 840: loss 0.382903
# batch 841: loss 0.331540
# batch 842: loss 0.129871
# batch 843: loss 0.341536
# batch 844: loss 0.218305
# batch 845: loss 0.282728
# batch 846: loss 0.379333
# batch 847: loss 0.098073
# batch 848: loss 0.201994
# batch 849: loss 0.126694
# batch 850: loss 0.151606
# batch 851: loss 0.237601
# batch 852: loss 0.179121
# batch 853: loss 0.181383
# batch 854: loss 0.178501
# batch 855: loss 0.136285
# batch 856: loss 0.110077
# batch 857: loss 0.529190
# batch 858: loss 0.206484
# batch 859: loss 0.262500
# batch 860: loss 0.193809
# batch 861: loss 0.130841
# batch 862: loss 0.411642
# batch 863: loss 0.150228
# batch 864: loss 0.113470
# batch 865: loss 0.105356
# batch 866: loss 0.420888
# batch 867: loss 0.240403
# batch 868: loss 0.208991
# batch 869: loss 0.217367
# batch 870: loss 0.207686
# batch 871: loss 0.193287
# batch 872: loss 0.117642
# batch 873: loss 0.130111
# batch 874: loss 0.131496
# batch 875: loss 0.109004
# batch 876: loss 0.215168
# batch 877: loss 0.124459
# batch 878: loss 0.288230
# batch 879: loss 0.099548
# batch 880: loss 0.361038
# batch 881: loss 0.293533
# batch 882: loss 0.091865
# batch 883: loss 0.087018
# batch 884: loss 0.172062
# batch 885: loss 0.065014
# batch 886: loss 0.134406
# batch 887: loss 0.405733
# batch 888: loss 0.072156
# batch 889: loss 0.382903
# batch 890: loss 0.259356
# batch 891: loss 0.289446
# batch 892: loss 0.269441
# batch 893: loss 0.077160
# batch 894: loss 0.114570
# batch 895: loss 0.132844
# batch 896: loss 0.167114
# batch 897: loss 0.220726
# batch 898: loss 0.143891
# batch 899: loss 0.343591
# batch 900: loss 0.203404
# batch 901: loss 0.180705
# batch 902: loss 0.230250
# batch 903: loss 0.273692
# batch 904: loss 0.342550
# batch 905: loss 0.293703
# batch 906: loss 0.197098
# batch 907: loss 0.178072
# batch 908: loss 0.146217
# batch 909: loss 0.132985
# batch 910: loss 0.166327
# batch 911: loss 0.180784
# batch 912: loss 0.109830
# batch 913: loss 0.210883
# batch 914: loss 0.107346
# batch 915: loss 0.071014
# batch 916: loss 0.234450
# batch 917: loss 0.343395
# batch 918: loss 0.257492
# batch 919: loss 0.184515
# batch 920: loss 0.154505
# batch 921: loss 0.055453
# batch 922: loss 0.088874
# batch 923: loss 0.156497
# batch 924: loss 0.205033
# batch 925: loss 0.064526
# batch 926: loss 0.258184
# batch 927: loss 0.271814
# batch 928: loss 0.081699
# batch 929: loss 0.254754
# batch 930: loss 0.060392
# batch 931: loss 0.250734
# batch 932: loss 0.310295
# batch 933: loss 0.237218
# batch 934: loss 0.246385
# batch 935: loss 0.069903
# batch 936: loss 0.101483
# batch 937: loss 0.116548
# batch 938: loss 0.103576
# batch 939: loss 0.184198
# batch 940: loss 0.062132
# batch 941: loss 0.133755
# batch 942: loss 0.136198
# batch 943: loss 0.185565
# batch 944: loss 0.083455
# batch 945: loss 0.133681
# batch 946: loss 0.157928
# batch 947: loss 0.069858
# batch 948: loss 0.061065
# batch 949: loss 0.411251
# batch 950: loss 0.211335
# batch 951: loss 0.162930
# batch 952: loss 0.404591
# batch 953: loss 0.218210
# batch 954: loss 0.185197
# batch 955: loss 0.143580
# batch 956: loss 0.108870
# batch 957: loss 0.147697
# batch 958: loss 0.215511
# batch 959: loss 0.144826
# batch 960: loss 0.211884
# batch 961: loss 0.108997
# batch 962: loss 0.039470
# batch 963: loss 0.143974
# batch 964: loss 0.362374
# batch 965: loss 0.151849
# batch 966: loss 0.089093
# batch 967: loss 0.083809
# batch 968: loss 0.153384
# batch 969: loss 0.281166
# batch 970: loss 0.119723
# batch 971: loss 0.091001
# batch 972: loss 0.213580
# batch 973: loss 0.184013
# batch 974: loss 0.202926
# batch 975: loss 0.272545
# batch 976: loss 0.051529
# batch 977: loss 0.222817
# batch 978: loss 0.100604
# batch 979: loss 0.120489
# batch 980: loss 0.136323
# batch 981: loss 0.138038
# batch 982: loss 0.199252
# batch 983: loss 0.218068
# batch 984: loss 0.351798
# batch 985: loss 0.124555
# batch 986: loss 0.124919
# batch 987: loss 0.243692
# batch 988: loss 0.102435
# batch 989: loss 0.204941
# batch 990: loss 0.163888
# batch 991: loss 0.077691
# batch 992: loss 0.187176
# batch 993: loss 0.046083
# batch 994: loss 0.140876
# batch 995: loss 0.025797
# batch 996: loss 0.184879
# batch 997: loss 0.059768
# batch 998: loss 0.105299
# batch 999: loss 0.138050
# batch 1000: loss 0.420731
# batch 1001: loss 0.221672
# batch 1002: loss 0.190499
# batch 1003: loss 0.135522
# batch 1004: loss 0.051034
# batch 1005: loss 0.162501
# batch 1006: loss 0.129995
# batch 1007: loss 0.159318
# batch 1008: loss 0.098475
# batch 1009: loss 0.134378
# batch 1010: loss 0.265503
# batch 1011: loss 0.144456
# batch 1012: loss 0.246559
# batch 1013: loss 0.138734
# batch 1014: loss 0.275510
# batch 1015: loss 0.245282
# batch 1016: loss 0.132593
# batch 1017: loss 0.064008
# batch 1018: loss 0.175865
# batch 1019: loss 0.183362
# batch 1020: loss 0.058840
# batch 1021: loss 0.158806
# batch 1022: loss 0.272246
# batch 1023: loss 0.169899
# batch 1024: loss 0.201355
# batch 1025: loss 0.340961
# batch 1026: loss 0.075122
# batch 1027: loss 0.167155
# batch 1028: loss 0.117008
# batch 1029: loss 0.153537
# batch 1030: loss 0.127558
# batch 1031: loss 0.086572
# batch 1032: loss 0.331036
# batch 1033: loss 0.243925
# batch 1034: loss 0.188483
# batch 1035: loss 0.260418
# batch 1036: loss 0.104490
# batch 1037: loss 0.178054
# batch 1038: loss 0.161230
# batch 1039: loss 0.119932
# batch 1040: loss 0.221940
# batch 1041: loss 0.199050
# batch 1042: loss 0.190945
# batch 1043: loss 0.165094
# batch 1044: loss 0.069412
# batch 1045: loss 0.267792
# batch 1046: loss 0.514079
# batch 1047: loss 0.195965
# batch 1048: loss 0.131500
# batch 1049: loss 0.138651
# batch 1050: loss 0.297312
# batch 1051: loss 0.166495
# batch 1052: loss 0.239966
# batch 1053: loss 0.183404
# batch 1054: loss 0.138992
# batch 1055: loss 0.173597
# batch 1056: loss 0.164348
# batch 1057: loss 0.338269
# batch 1058: loss 0.224385
# batch 1059: loss 0.114738
# batch 1060: loss 0.317868
# batch 1061: loss 0.175718
# batch 1062: loss 0.167435
# batch 1063: loss 0.101868
# batch 1064: loss 0.128638
# batch 1065: loss 0.116982
# batch 1066: loss 0.183146
# batch 1067: loss 0.053570
# batch 1068: loss 0.180469
# batch 1069: loss 0.172836
# batch 1070: loss 0.159771
# batch 1071: loss 0.318537
# batch 1072: loss 0.248573
# batch 1073: loss 0.215787
# batch 1074: loss 0.232462
# batch 1075: loss 0.104195
# batch 1076: loss 0.033191
# batch 1077: loss 0.132443
# batch 1078: loss 0.068071
# batch 1079: loss 0.100517
# batch 1080: loss 0.162045
# batch 1081: loss 0.184910
# batch 1082: loss 0.295874
# batch 1083: loss 0.146044
# batch 1084: loss 0.226964
# batch 1085: loss 0.141649
# batch 1086: loss 0.189170
# batch 1087: loss 0.134313
# batch 1088: loss 0.247788
# batch 1089: loss 0.275610
# batch 1090: loss 0.158942
# batch 1091: loss 0.216687
# batch 1092: loss 0.147014
# batch 1093: loss 0.198363
# batch 1094: loss 0.172136
# batch 1095: loss 0.149579
# batch 1096: loss 0.060952
# batch 1097: loss 0.040467
# batch 1098: loss 0.055201
# batch 1099: loss 0.287020
# batch 1100: loss 0.104091
# batch 1101: loss 0.358016
# batch 1102: loss 0.244626
# batch 1103: loss 0.070782
# batch 1104: loss 0.164446
# batch 1105: loss 0.369988
# batch 1106: loss 0.101721
# batch 1107: loss 0.140403
# batch 1108: loss 0.137073
# batch 1109: loss 0.161237
# batch 1110: loss 0.115618
# batch 1111: loss 0.279630
# batch 1112: loss 0.123312
# batch 1113: loss 0.160028
# batch 1114: loss 0.098691
# batch 1115: loss 0.178156
# batch 1116: loss 0.141854
# batch 1117: loss 0.199348
# batch 1118: loss 0.198550
# batch 1119: loss 0.062935
# batch 1120: loss 0.089456
# batch 1121: loss 0.289674
# batch 1122: loss 0.123029
# batch 1123: loss 0.096937
# batch 1124: loss 0.374513
# batch 1125: loss 0.234708
# batch 1126: loss 0.261032
# batch 1127: loss 0.145761
# batch 1128: loss 0.161425
# batch 1129: loss 0.125237
# batch 1130: loss 0.158624
# batch 1131: loss 0.282945
# batch 1132: loss 0.195126
# batch 1133: loss 0.076646
# batch 1134: loss 0.095990
# batch 1135: loss 0.391847
# batch 1136: loss 0.137457
# batch 1137: loss 0.142790
# batch 1138: loss 0.127859
# batch 1139: loss 0.450471
# batch 1140: loss 0.137182
# batch 1141: loss 0.192913
# batch 1142: loss 0.065446
# batch 1143: loss 0.285192
# batch 1144: loss 0.137559
# batch 1145: loss 0.172494
# batch 1146: loss 0.347633
# batch 1147: loss 0.147720
# batch 1148: loss 0.206374
# batch 1149: loss 0.089403
# batch 1150: loss 0.141253
# batch 1151: loss 0.203308
# batch 1152: loss 0.242827
# batch 1153: loss 0.169768
# batch 1154: loss 0.411701
# batch 1155: loss 0.069772
# batch 1156: loss 0.076780
# batch 1157: loss 0.155986
# batch 1158: loss 0.283216
# batch 1159: loss 0.216578
# batch 1160: loss 0.121639
# batch 1161: loss 0.115410
# batch 1162: loss 0.150909
# batch 1163: loss 0.075329
# batch 1164: loss 0.055340
# batch 1165: loss 0.186300
# batch 1166: loss 0.125600
# batch 1167: loss 0.044973
# batch 1168: loss 0.162950
# batch 1169: loss 0.054685
# batch 1170: loss 0.256132
# batch 1171: loss 0.098625
# batch 1172: loss 0.246531
# batch 1173: loss 0.066365
# batch 1174: loss 0.130142
# batch 1175: loss 0.132501
# batch 1176: loss 0.181783
# batch 1177: loss 0.315394
# batch 1178: loss 0.110092
# batch 1179: loss 0.082126
# batch 1180: loss 0.111450
# batch 1181: loss 0.169156
# batch 1182: loss 0.190998
# batch 1183: loss 0.092085
# batch 1184: loss 0.107092
# batch 1185: loss 0.164891
# batch 1186: loss 0.332559
# batch 1187: loss 0.111074
# batch 1188: loss 0.119513
# batch 1189: loss 0.190063
# batch 1190: loss 0.227635
# batch 1191: loss 0.120781
# batch 1192: loss 0.180272
# batch 1193: loss 0.202578
# batch 1194: loss 0.156711
# batch 1195: loss 0.146426
# batch 1196: loss 0.251191
# batch 1197: loss 0.253571
# batch 1198: loss 0.066799
# batch 1199: loss 0.192815
# batch 1200: loss 0.078148
# batch 1201: loss 0.172014
# batch 1202: loss 0.220007
# batch 1203: loss 0.124571
# batch 1204: loss 0.084770
# batch 1205: loss 0.186659
# batch 1206: loss 0.249211
# batch 1207: loss 0.143073
# batch 1208: loss 0.202019
# batch 1209: loss 0.331086
# batch 1210: loss 0.085989
# batch 1211: loss 0.141990
# batch 1212: loss 0.347639
# batch 1213: loss 0.116378
# batch 1214: loss 0.163603
# batch 1215: loss 0.040215
# batch 1216: loss 0.145016
# batch 1217: loss 0.225090
# batch 1218: loss 0.056967
# batch 1219: loss 0.060090
# batch 1220: loss 0.100084
# batch 1221: loss 0.071109
# batch 1222: loss 0.153615
# batch 1223: loss 0.152455
# batch 1224: loss 0.171470
# batch 1225: loss 0.164237
# batch 1226: loss 0.114547
# batch 1227: loss 0.089425
# batch 1228: loss 0.083521
# batch 1229: loss 0.315149
# batch 1230: loss 0.184468
# batch 1231: loss 0.074297
# batch 1232: loss 0.035482
# batch 1233: loss 0.189330
# batch 1234: loss 0.041342
# batch 1235: loss 0.161250
# batch 1236: loss 0.335284
# batch 1237: loss 0.128490
# batch 1238: loss 0.078290
# batch 1239: loss 0.242610
# batch 1240: loss 0.273053
# batch 1241: loss 0.289280
# batch 1242: loss 0.236783
# batch 1243: loss 0.099866
# batch 1244: loss 0.117254
# batch 1245: loss 0.288117
# batch 1246: loss 0.096540
# batch 1247: loss 0.121415
# batch 1248: loss 0.090402
# batch 1249: loss 0.211734
# batch 1250: loss 0.092526
# batch 1251: loss 0.115921
# batch 1252: loss 0.094028
# batch 1253: loss 0.177846
# batch 1254: loss 0.124719
# batch 1255: loss 0.091074
# batch 1256: loss 0.139736
# batch 1257: loss 0.152156
# batch 1258: loss 0.118257
# batch 1259: loss 0.197808
# batch 1260: loss 0.134833
# batch 1261: loss 0.393674
# batch 1262: loss 0.093825
# batch 1263: loss 0.184871
# batch 1264: loss 0.092465
# batch 1265: loss 0.028934
# batch 1266: loss 0.120180
# batch 1267: loss 0.258720
# batch 1268: loss 0.109309
# batch 1269: loss 0.227758
# batch 1270: loss 0.135351
# batch 1271: loss 0.054203
# batch 1272: loss 0.088787
# batch 1273: loss 0.167766
# batch 1274: loss 0.105678
# batch 1275: loss 0.209318
# batch 1276: loss 0.082958
# batch 1277: loss 0.224294
# batch 1278: loss 0.025104
# batch 1279: loss 0.129104
# batch 1280: loss 0.197245
# batch 1281: loss 0.105258
# batch 1282: loss 0.149394
# batch 1283: loss 0.097700
# batch 1284: loss 0.204136
# batch 1285: loss 0.089922
# batch 1286: loss 0.229219
# batch 1287: loss 0.069994
# batch 1288: loss 0.211128
# batch 1289: loss 0.148399
# batch 1290: loss 0.178499
# batch 1291: loss 0.097012
# batch 1292: loss 0.251046
# batch 1293: loss 0.104796
# batch 1294: loss 0.293640
# batch 1295: loss 0.142723
# batch 1296: loss 0.147843
# batch 1297: loss 0.106165
# batch 1298: loss 0.063722
# batch 1299: loss 0.238413
# batch 1300: loss 0.079892
# batch 1301: loss 0.088524
# batch 1302: loss 0.159613
# batch 1303: loss 0.186961
# batch 1304: loss 0.046958
# batch 1305: loss 0.188693
# batch 1306: loss 0.156161
# batch 1307: loss 0.108985
# batch 1308: loss 0.047423
# batch 1309: loss 0.154977
# batch 1310: loss 0.078709
# batch 1311: loss 0.045318
# batch 1312: loss 0.104783
# batch 1313: loss 0.103046
# batch 1314: loss 0.118902
# batch 1315: loss 0.103284
# batch 1316: loss 0.146186
# batch 1317: loss 0.101434
# batch 1318: loss 0.046808
# batch 1319: loss 0.136276
# batch 1320: loss 0.037390
# batch 1321: loss 0.178504
# batch 1322: loss 0.416227
# batch 1323: loss 0.167655
# batch 1324: loss 0.136429
# batch 1325: loss 0.287841
# batch 1326: loss 0.132513
# batch 1327: loss 0.111092
# batch 1328: loss 0.185027
# batch 1329: loss 0.026464
# batch 1330: loss 0.299636
# batch 1331: loss 0.221130
# batch 1332: loss 0.080860
# batch 1333: loss 0.099459
# batch 1334: loss 0.130362
# batch 1335: loss 0.249126
# batch 1336: loss 0.101354
# batch 1337: loss 0.241729
# batch 1338: loss 0.342216
# batch 1339: loss 0.052977
# batch 1340: loss 0.111645
# batch 1341: loss 0.110147
# batch 1342: loss 0.139788
# batch 1343: loss 0.108534
# batch 1344: loss 0.085366
# batch 1345: loss 0.128156
# batch 1346: loss 0.060470
# batch 1347: loss 0.132505
# batch 1348: loss 0.156410
# batch 1349: loss 0.253795
# batch 1350: loss 0.174932
# batch 1351: loss 0.073244
# batch 1352: loss 0.056714
# batch 1353: loss 0.239767
# batch 1354: loss 0.254651
# batch 1355: loss 0.291897
# batch 1356: loss 0.271092
# batch 1357: loss 0.138710
# batch 1358: loss 0.104887
# batch 1359: loss 0.081705
# batch 1360: loss 0.043128
# batch 1361: loss 0.349689
# batch 1362: loss 0.033049
# batch 1363: loss 0.064083
# batch 1364: loss 0.208372
# batch 1365: loss 0.148222
# batch 1366: loss 0.236475
# batch 1367: loss 0.289782
# batch 1368: loss 0.065606
# batch 1369: loss 0.113813
# batch 1370: loss 0.262125
# batch 1371: loss 0.247859
# batch 1372: loss 0.212394
# batch 1373: loss 0.086964
# batch 1374: loss 0.168939
# batch 1375: loss 0.182743
# batch 1376: loss 0.090822
# batch 1377: loss 0.248153
# batch 1378: loss 0.113208
# batch 1379: loss 0.126172
# batch 1380: loss 0.083491
# batch 1381: loss 0.219804
# batch 1382: loss 0.149425
# batch 1383: loss 0.239233
# batch 1384: loss 0.104091
# batch 1385: loss 0.192231
# batch 1386: loss 0.111784
# batch 1387: loss 0.115367
# batch 1388: loss 0.062866
# batch 1389: loss 0.115969
# batch 1390: loss 0.042419
# batch 1391: loss 0.242165
# batch 1392: loss 0.036536
# batch 1393: loss 0.109172
# batch 1394: loss 0.085614
# batch 1395: loss 0.083338
# batch 1396: loss 0.112095
# batch 1397: loss 0.200775
# batch 1398: loss 0.101354
# batch 1399: loss 0.139358
# batch 1400: loss 0.071492
# batch 1401: loss 0.162166
# batch 1402: loss 0.104944
# batch 1403: loss 0.349506
# batch 1404: loss 0.244902
# batch 1405: loss 0.069210
# batch 1406: loss 0.479924
# batch 1407: loss 0.148947
# batch 1408: loss 0.225131
# batch 1409: loss 0.116476
# batch 1410: loss 0.214588
# batch 1411: loss 0.207137
# batch 1412: loss 0.266488
# batch 1413: loss 0.583111
# batch 1414: loss 0.092770
# batch 1415: loss 0.058871
# batch 1416: loss 0.121335
# batch 1417: loss 0.140241
# batch 1418: loss 0.256209
# batch 1419: loss 0.128638
# batch 1420: loss 0.092129
# batch 1421: loss 0.146026
# batch 1422: loss 0.120414
# batch 1423: loss 0.261406
# batch 1424: loss 0.065876
# batch 1425: loss 0.209533
# batch 1426: loss 0.088779
# batch 1427: loss 0.241011
# batch 1428: loss 0.092715
# batch 1429: loss 0.246741
# batch 1430: loss 0.123484
# batch 1431: loss 0.066364
# batch 1432: loss 0.050739
# batch 1433: loss 0.137680
# batch 1434: loss 0.292936
# batch 1435: loss 0.087057
# batch 1436: loss 0.096368
# batch 1437: loss 0.176859
# batch 1438: loss 0.020220
# batch 1439: loss 0.349308
# batch 1440: loss 0.071414
# batch 1441: loss 0.030593
# batch 1442: loss 0.046290
# batch 1443: loss 0.165737
# batch 1444: loss 0.034977
# batch 1445: loss 0.062240
# batch 1446: loss 0.172297
# batch 1447: loss 0.216633
# batch 1448: loss 0.043042
# batch 1449: loss 0.174224
# batch 1450: loss 0.145983
# batch 1451: loss 0.134131
# batch 1452: loss 0.098277
# batch 1453: loss 0.181984
# batch 1454: loss 0.362068
# batch 1455: loss 0.158145
# batch 1456: loss 0.054372
# batch 1457: loss 0.087588
# batch 1458: loss 0.350109
# batch 1459: loss 0.068975
# batch 1460: loss 0.062896
# batch 1461: loss 0.130720
# batch 1462: loss 0.302029
# batch 1463: loss 0.058014
# batch 1464: loss 0.063026
# batch 1465: loss 0.117363
# batch 1466: loss 0.098201
# batch 1467: loss 0.347684
# batch 1468: loss 0.156091
# batch 1469: loss 0.078081
# batch 1470: loss 0.081722
# batch 1471: loss 0.066963
# batch 1472: loss 0.071637
# batch 1473: loss 0.258883
# batch 1474: loss 0.242655
# batch 1475: loss 0.080624
# batch 1476: loss 0.088024
# batch 1477: loss 0.144153
# batch 1478: loss 0.134802
# batch 1479: loss 0.167635
# batch 1480: loss 0.113625
# batch 1481: loss 0.114125
# batch 1482: loss 0.052376
# batch 1483: loss 0.196016
# batch 1484: loss 0.049378
# batch 1485: loss 0.201180
# batch 1486: loss 0.344473
# batch 1487: loss 0.078902
# batch 1488: loss 0.135800
# batch 1489: loss 0.096853
# batch 1490: loss 0.235260
# batch 1491: loss 0.214151
# batch 1492: loss 0.256638
# batch 1493: loss 0.241236
# batch 1494: loss 0.149234
# batch 1495: loss 0.132765
# batch 1496: loss 0.177025
# batch 1497: loss 0.279528
# batch 1498: loss 0.075261
# batch 1499: loss 0.228800
# batch 1500: loss 0.234680
# batch 1501: loss 0.126169
# batch 1502: loss 0.395808
# batch 1503: loss 0.231955
# batch 1504: loss 0.227941
# batch 1505: loss 0.125706
# batch 1506: loss 0.192508
# batch 1507: loss 0.076904
# batch 1508: loss 0.144365
# batch 1509: loss 0.194669
# batch 1510: loss 0.220295
# batch 1511: loss 0.156191
# batch 1512: loss 0.047045
# batch 1513: loss 0.097614
# batch 1514: loss 0.041545
# batch 1515: loss 0.151148
# batch 1516: loss 0.190504
# batch 1517: loss 0.205674
# batch 1518: loss 0.051770
# batch 1519: loss 0.043682
# batch 1520: loss 0.078388
# batch 1521: loss 0.189889
# batch 1522: loss 0.138541
# batch 1523: loss 0.053676
# batch 1524: loss 0.112906
# batch 1525: loss 0.078576
# batch 1526: loss 0.147625
# batch 1527: loss 0.327391
# batch 1528: loss 0.140788
# batch 1529: loss 0.074225
# batch 1530: loss 0.149329
# batch 1531: loss 0.148789
# batch 1532: loss 0.055072
# batch 1533: loss 0.110114
# batch 1534: loss 0.158122
# batch 1535: loss 0.072014
# batch 1536: loss 0.115238
# batch 1537: loss 0.076967
# batch 1538: loss 0.030757
# batch 1539: loss 0.058307
# batch 1540: loss 0.072207
# batch 1541: loss 0.080964
# batch 1542: loss 0.127659
# batch 1543: loss 0.165082
# batch 1544: loss 0.068668
# batch 1545: loss 0.081472
# batch 1546: loss 0.178694
# batch 1547: loss 0.075574
# batch 1548: loss 0.070906
# batch 1549: loss 0.125635
# batch 1550: loss 0.105736
# batch 1551: loss 0.304338
# batch 1552: loss 0.146639
# batch 1553: loss 0.087370
# batch 1554: loss 0.151243
# batch 1555: loss 0.042111
# batch 1556: loss 0.223735
# batch 1557: loss 0.141168
# batch 1558: loss 0.091574
# batch 1559: loss 0.075041
# batch 1560: loss 0.076896
# batch 1561: loss 0.168871
# batch 1562: loss 0.063838
# batch 1563: loss 0.473740
# batch 1564: loss 0.049162
# batch 1565: loss 0.069680
# batch 1566: loss 0.123171
# batch 1567: loss 0.146418
# batch 1568: loss 0.059977
# batch 1569: loss 0.139863
# batch 1570: loss 0.247837
# batch 1571: loss 0.054735
# batch 1572: loss 0.052765
# batch 1573: loss 0.305094
# batch 1574: loss 0.184765
# batch 1575: loss 0.094580
# batch 1576: loss 0.130039
# batch 1577: loss 0.088350
# batch 1578: loss 0.316044
# batch 1579: loss 0.116500
# batch 1580: loss 0.124243
# batch 1581: loss 0.059780
# batch 1582: loss 0.151480
# batch 1583: loss 0.213273
# batch 1584: loss 0.221869
# batch 1585: loss 0.187934
# batch 1586: loss 0.290940
# batch 1587: loss 0.235334
# batch 1588: loss 0.177662
# batch 1589: loss 0.168052
# batch 1590: loss 0.253999
# batch 1591: loss 0.090047
# batch 1592: loss 0.054643
# batch 1593: loss 0.161938
# batch 1594: loss 0.119123
# batch 1595: loss 0.075018
# batch 1596: loss 0.170955
# batch 1597: loss 0.253076
# batch 1598: loss 0.067298
# batch 1599: loss 0.350208
# batch 1600: loss 0.178470
# batch 1601: loss 0.076063
# batch 1602: loss 0.134101
# batch 1603: loss 0.076455
# batch 1604: loss 0.157103
# batch 1605: loss 0.191319
# batch 1606: loss 0.162892
# batch 1607: loss 0.088955
# batch 1608: loss 0.150547
# batch 1609: loss 0.103722
# batch 1610: loss 0.169351
# batch 1611: loss 0.052835
# batch 1612: loss 0.297261
# batch 1613: loss 0.092694
# batch 1614: loss 0.189981
# batch 1615: loss 0.118696
# batch 1616: loss 0.226650
# batch 1617: loss 0.110365
# batch 1618: loss 0.162833
# batch 1619: loss 0.033219
# batch 1620: loss 0.103946
# batch 1621: loss 0.045823
# batch 1622: loss 0.109289
# batch 1623: loss 0.083348
# batch 1624: loss 0.014741
# batch 1625: loss 0.045235
# batch 1626: loss 0.082011
# batch 1627: loss 0.364057
# batch 1628: loss 0.164679
# batch 1629: loss 0.261459
# batch 1630: loss 0.199768
# batch 1631: loss 0.240363
# batch 1632: loss 0.220144
# batch 1633: loss 0.046791
# batch 1634: loss 0.175058
# batch 1635: loss 0.118021
# batch 1636: loss 0.106616
# batch 1637: loss 0.058514
# batch 1638: loss 0.057063
# batch 1639: loss 0.094125
# batch 1640: loss 0.158819
# batch 1641: loss 0.107111
# batch 1642: loss 0.104128
# batch 1643: loss 0.211585
# batch 1644: loss 0.113843
# batch 1645: loss 0.323188
# batch 1646: loss 0.040441
# batch 1647: loss 0.014650
# batch 1648: loss 0.127435
# batch 1649: loss 0.263396
# batch 1650: loss 0.153434
# batch 1651: loss 0.093186
# batch 1652: loss 0.128088
# batch 1653: loss 0.086630
# batch 1654: loss 0.138069
# batch 1655: loss 0.131119
# batch 1656: loss 0.279298
# batch 1657: loss 0.121592
# batch 1658: loss 0.214676
# batch 1659: loss 0.064043
# batch 1660: loss 0.072967
# batch 1661: loss 0.107170
# batch 1662: loss 0.136755
# batch 1663: loss 0.073385
# batch 1664: loss 0.172940
# batch 1665: loss 0.220420
# batch 1666: loss 0.134700
# batch 1667: loss 0.110977
# batch 1668: loss 0.148037
# batch 1669: loss 0.058294
# batch 1670: loss 0.035662
# batch 1671: loss 0.092024
# batch 1672: loss 0.420679
# batch 1673: loss 0.097964
# batch 1674: loss 0.100898
# batch 1675: loss 0.067300
# batch 1676: loss 0.108239
# batch 1677: loss 0.193523
# batch 1678: loss 0.165892
# batch 1679: loss 0.095550
# batch 1680: loss 0.092584
# batch 1681: loss 0.247282
# batch 1682: loss 0.228319
# batch 1683: loss 0.070268
# batch 1684: loss 0.084279
# batch 1685: loss 0.182855
# batch 1686: loss 0.140833
# batch 1687: loss 0.206811
# batch 1688: loss 0.145163
# batch 1689: loss 0.265193
# batch 1690: loss 0.167261
# batch 1691: loss 0.260158
# batch 1692: loss 0.128737
# batch 1693: loss 0.081282
# batch 1694: loss 0.051220
# batch 1695: loss 0.070764
# batch 1696: loss 0.039843
# batch 1697: loss 0.207982
# batch 1698: loss 0.136247
# batch 1699: loss 0.197289
# batch 1700: loss 0.195553
# batch 1701: loss 0.132938
# batch 1702: loss 0.137756
# batch 1703: loss 0.155729
# batch 1704: loss 0.272026
# batch 1705: loss 0.065599
# batch 1706: loss 0.160141
# batch 1707: loss 0.053163
# batch 1708: loss 0.067077
# batch 1709: loss 0.231144
# batch 1710: loss 0.197707
# batch 1711: loss 0.088708
# batch 1712: loss 0.055799
# batch 1713: loss 0.062521
# batch 1714: loss 0.053512
# batch 1715: loss 0.045229
# batch 1716: loss 0.130803
# batch 1717: loss 0.206993
# batch 1718: loss 0.185678
# batch 1719: loss 0.059020
# batch 1720: loss 0.080368
# batch 1721: loss 0.072321
# batch 1722: loss 0.266243
# batch 1723: loss 0.208412
# batch 1724: loss 0.147134
# batch 1725: loss 0.096339
# batch 1726: loss 0.108012
# batch 1727: loss 0.278675
# batch 1728: loss 0.050363
# batch 1729: loss 0.318016
# batch 1730: loss 0.131186
# batch 1731: loss 0.036591
# batch 1732: loss 0.051354
# batch 1733: loss 0.061067
# batch 1734: loss 0.057310
# batch 1735: loss 0.053751
# batch 1736: loss 0.052232
# batch 1737: loss 0.254940
# batch 1738: loss 0.357157
# batch 1739: loss 0.091878
# batch 1740: loss 0.172498
# batch 1741: loss 0.198864
# batch 1742: loss 0.064732
# batch 1743: loss 0.077720
# batch 1744: loss 0.085582
# batch 1745: loss 0.092202
# batch 1746: loss 0.047168
# batch 1747: loss 0.200358
# batch 1748: loss 0.138350
# batch 1749: loss 0.296820
# batch 1750: loss 0.198791
# batch 1751: loss 0.048930
# batch 1752: loss 0.052116
# batch 1753: loss 0.090277
# batch 1754: loss 0.100162
# batch 1755: loss 0.068797
# batch 1756: loss 0.186088
# batch 1757: loss 0.078895
# batch 1758: loss 0.128436
# batch 1759: loss 0.177624
# batch 1760: loss 0.100385
# batch 1761: loss 0.061167
# batch 1762: loss 0.118370
# batch 1763: loss 0.167304
# batch 1764: loss 0.130915
# batch 1765: loss 0.102420
# batch 1766: loss 0.109540
# batch 1767: loss 0.032952
# batch 1768: loss 0.056632
# batch 1769: loss 0.155962
# batch 1770: loss 0.073325
# batch 1771: loss 0.059057
# batch 1772: loss 0.110712
# batch 1773: loss 0.111568
# batch 1774: loss 0.192454
# batch 1775: loss 0.013504
# batch 1776: loss 0.242761
# batch 1777: loss 0.103813
# batch 1778: loss 0.116149
# batch 1779: loss 0.153916
# batch 1780: loss 0.198927
# batch 1781: loss 0.099037
# batch 1782: loss 0.136138
# batch 1783: loss 0.055792
# batch 1784: loss 0.156760
# batch 1785: loss 0.057718
# batch 1786: loss 0.045214
# batch 1787: loss 0.077677
# batch 1788: loss 0.046822
# batch 1789: loss 0.340141
# batch 1790: loss 0.074773
# batch 1791: loss 0.102144
# batch 1792: loss 0.138573
# batch 1793: loss 0.258644
# batch 1794: loss 0.303622
# batch 1795: loss 0.079169
# batch 1796: loss 0.172371
# batch 1797: loss 0.227495
# batch 1798: loss 0.084988
# batch 1799: loss 0.083132
# batch 1800: loss 0.173409
# batch 1801: loss 0.363919
# batch 1802: loss 0.061524
# batch 1803: loss 0.049953
# batch 1804: loss 0.164410
# batch 1805: loss 0.192307
# batch 1806: loss 0.034219
# batch 1807: loss 0.115042
# batch 1808: loss 0.066953
# batch 1809: loss 0.140261
# batch 1810: loss 0.043393
# batch 1811: loss 0.065027
# batch 1812: loss 0.142527
# batch 1813: loss 0.102270
# batch 1814: loss 0.079595
# batch 1815: loss 0.049189
# batch 1816: loss 0.153152
# batch 1817: loss 0.092822
# batch 1818: loss 0.146357
# batch 1819: loss 0.048022
# batch 1820: loss 0.080227
# batch 1821: loss 0.106864
# batch 1822: loss 0.135372
# batch 1823: loss 0.079397
# batch 1824: loss 0.340197
# batch 1825: loss 0.178572
# batch 1826: loss 0.112875
# batch 1827: loss 0.039692
# batch 1828: loss 0.222310
# batch 1829: loss 0.137851
# batch 1830: loss 0.102378
# batch 1831: loss 0.053729
# batch 1832: loss 0.095561
# batch 1833: loss 0.038466
# batch 1834: loss 0.108849
# batch 1835: loss 0.112066
# batch 1836: loss 0.094677
# batch 1837: loss 0.128253
# batch 1838: loss 0.071192
# batch 1839: loss 0.121870
# batch 1840: loss 0.169639
# batch 1841: loss 0.352185
# batch 1842: loss 0.046260
# batch 1843: loss 0.067930
# batch 1844: loss 0.036907
# batch 1845: loss 0.099485
# batch 1846: loss 0.029413
# batch 1847: loss 0.346915
# batch 1848: loss 0.128829
# batch 1849: loss 0.126482
# batch 1850: loss 0.128972
# batch 1851: loss 0.276174
# batch 1852: loss 0.123226
# batch 1853: loss 0.046021
# batch 1854: loss 0.141198
# batch 1855: loss 0.047646
# batch 1856: loss 0.203665
# batch 1857: loss 0.034325
# batch 1858: loss 0.204209
# batch 1859: loss 0.219481
# batch 1860: loss 0.122915
# batch 1861: loss 0.056946
# batch 1862: loss 0.489358
# batch 1863: loss 0.123588
# batch 1864: loss 0.272445
# batch 1865: loss 0.190736
# batch 1866: loss 0.047237
# batch 1867: loss 0.107207
# batch 1868: loss 0.062011
# batch 1869: loss 0.145868
# batch 1870: loss 0.066792
# batch 1871: loss 0.047704
# batch 1872: loss 0.124727
# batch 1873: loss 0.071862
# batch 1874: loss 0.086174
# batch 1875: loss 0.170033
# batch 1876: loss 0.103146
# batch 1877: loss 0.220124
# batch 1878: loss 0.135499
# batch 1879: loss 0.038500
# batch 1880: loss 0.089945
# batch 1881: loss 0.051257
# batch 1882: loss 0.317306
# batch 1883: loss 0.177918
# batch 1884: loss 0.033783
# batch 1885: loss 0.105676
# batch 1886: loss 0.167451
# batch 1887: loss 0.087038
# ...
# batch 5385: loss 0.063598
# batch 5386: loss 0.136652
# batch 5387: loss 0.129897
# batch 5388: loss 0.058785
# batch 5389: loss 0.110625
# batch 5390: loss 0.069909
# batch 5391: loss 0.207985
# batch 5392: loss 0.065384
# batch 5393: loss 0.070597
# batch 5394: loss 0.064034
# batch 5395: loss 0.005665
# batch 5396: loss 0.188256
# batch 5397: loss 0.016898
# batch 5398: loss 0.106200
# batch 5399: loss 0.031887
# batch 5400: loss 0.017881
# batch 5401: loss 0.050788
# batch 5402: loss 0.006958
# batch 5403: loss 0.016874
# batch 5404: loss 0.005474
# batch 5405: loss 0.063982
# batch 5406: loss 0.039913
# batch 5407: loss 0.006926
# batch 5408: loss 0.007810
# batch 5409: loss 0.010707
# batch 5410: loss 0.142064
# batch 5411: loss 0.138669
# batch 5412: loss 0.032523
# batch 5413: loss 0.092054
# batch 5414: loss 0.023767
# batch 5415: loss 0.074167
# batch 5416: loss 0.011522
# batch 5417: loss 0.042023
# batch 5418: loss 0.020976
# batch 5419: loss 0.096913
# batch 5420: loss 0.057993
# batch 5421: loss 0.092937
# batch 5422: loss 0.057722
# batch 5423: loss 0.114676
# batch 5424: loss 0.025200
# batch 5425: loss 0.087237
# batch 5426: loss 0.093405
# batch 5427: loss 0.167359
# batch 5428: loss 0.011283
# batch 5429: loss 0.006743
# batch 5430: loss 0.022876
# batch 5431: loss 0.003931
# batch 5432: loss 0.021262
# batch 5433: loss 0.030574
# batch 5434: loss 0.012034
# batch 5435: loss 0.090697
# batch 5436: loss 0.092357
# batch 5437: loss 0.113950
# batch 5438: loss 0.123439
# batch 5439: loss 0.013800
# batch 5440: loss 0.023795
# batch 5441: loss 0.008705
# batch 5442: loss 0.014342
# batch 5443: loss 0.027698
# batch 5444: loss 0.038832
# batch 5445: loss 0.085601
# batch 5446: loss 0.072817
# batch 5447: loss 0.104947
# batch 5448: loss 0.014224
# batch 5449: loss 0.027427
# batch 5450: loss 0.228265
# batch 5451: loss 0.098507
# batch 5452: loss 0.054569
# batch 5453: loss 0.009444
# batch 5454: loss 0.043969
# batch 5455: loss 0.372177
# batch 5456: loss 0.099844
# batch 5457: loss 0.012945
# batch 5458: loss 0.021299
# batch 5459: loss 0.047247
# batch 5460: loss 0.248241
# batch 5461: loss 0.012189
# batch 5462: loss 0.029794
# batch 5463: loss 0.021126
# batch 5464: loss 0.014294
# batch 5465: loss 0.006415
# batch 5466: loss 0.040874
# batch 5467: loss 0.025984
# batch 5468: loss 0.006623
# batch 5469: loss 0.027491
# batch 5470: loss 0.024940
# batch 5471: loss 0.115021
# batch 5472: loss 0.139969
# batch 5473: loss 0.082181
# batch 5474: loss 0.139408
# batch 5475: loss 0.021707
# batch 5476: loss 0.053905
# batch 5477: loss 0.109725
# batch 5478: loss 0.041578
# batch 5479: loss 0.002398
# batch 5480: loss 0.006997
# batch 5481: loss 0.049239
# batch 5482: loss 0.060545
# batch 5483: loss 0.053990
# batch 5484: loss 0.009779
# batch 5485: loss 0.033193
# batch 5486: loss 0.024400
# batch 5487: loss 0.075864
# batch 5488: loss 0.025524
# batch 5489: loss 0.044272
# batch 5490: loss 0.057631
# batch 5491: loss 0.026918
# batch 5492: loss 0.022939
# batch 5493: loss 0.054178
# batch 5494: loss 0.080048
# batch 5495: loss 0.141592
# batch 5496: loss 0.095008
# batch 5497: loss 0.010179
# batch 5498: loss 0.084860
# batch 5499: loss 0.120971
# batch 5500: loss 0.058384
# batch 5501: loss 0.014677
# batch 5502: loss 0.094086
# batch 5503: loss 0.126475
# batch 5504: loss 0.056116
# batch 5505: loss 0.055857
# batch 5506: loss 0.117976
# batch 5507: loss 0.025234
# batch 5508: loss 0.097348
# batch 5509: loss 0.036941
# batch 5510: loss 0.051871
# batch 5511: loss 0.026497
# batch 5512: loss 0.111751
# batch 5513: loss 0.014867
# batch 5514: loss 0.294503
# batch 5515: loss 0.029047
# batch 5516: loss 0.096983
# batch 5517: loss 0.016600
# batch 5518: loss 0.016615
# batch 5519: loss 0.020467
# batch 5520: loss 0.024160
# batch 5521: loss 0.159117
# batch 5522: loss 0.003186
# batch 5523: loss 0.054409
# batch 5524: loss 0.020063
# batch 5525: loss 0.027969
# batch 5526: loss 0.039154
# batch 5527: loss 0.039024
# batch 5528: loss 0.034901
# batch 5529: loss 0.026477
# batch 5530: loss 0.030970
# batch 5531: loss 0.052812
# batch 5532: loss 0.010284
# batch 5533: loss 0.017243
# batch 5534: loss 0.095005
# batch 5535: loss 0.017422
# batch 5536: loss 0.015276
# batch 5537: loss 0.006441
# batch 5538: loss 0.088084
# batch 5539: loss 0.020170
# batch 5540: loss 0.030549
# batch 5541: loss 0.060231
# batch 5542: loss 0.069409
# batch 5543: loss 0.026616
# batch 5544: loss 0.059731
# batch 5545: loss 0.110317
# batch 5546: loss 0.089001
# batch 5547: loss 0.021990
# batch 5548: loss 0.122364
# batch 5549: loss 0.069340
# batch 5550: loss 0.019467
# batch 5551: loss 0.218122
# batch 5552: loss 0.002835
# batch 5553: loss 0.008220
# batch 5554: loss 0.095491
# batch 5555: loss 0.092858
# batch 5556: loss 0.027430
# batch 5557: loss 0.008568
# batch 5558: loss 0.106977
# batch 5559: loss 0.175429
# batch 5560: loss 0.025329
# batch 5561: loss 0.208684
# batch 5562: loss 0.243081
# batch 5563: loss 0.033566
# batch 5564: loss 0.024985
# batch 5565: loss 0.181407
# batch 5566: loss 0.050450
# batch 5567: loss 0.087702
# batch 5568: loss 0.018966
# batch 5569: loss 0.031528
# batch 5570: loss 0.024550
# batch 5571: loss 0.077935
# batch 5572: loss 0.126999
# batch 5573: loss 0.161085
# batch 5574: loss 0.049218
# batch 5575: loss 0.280053
# batch 5576: loss 0.022608
# batch 5577: loss 0.204859
# batch 5578: loss 0.089473
# batch 5579: loss 0.007908
# batch 5580: loss 0.007137
# batch 5581: loss 0.059095
# batch 5582: loss 0.071580
# batch 5583: loss 0.099173
# batch 5584: loss 0.223126
# batch 5585: loss 0.095643
# batch 5586: loss 0.005374
# batch 5587: loss 0.058599
# batch 5588: loss 0.020611
# batch 5589: loss 0.041734
# batch 5590: loss 0.065461
# batch 5591: loss 0.077486
# batch 5592: loss 0.031138
# batch 5593: loss 0.074591
# batch 5594: loss 0.111810
# batch 5595: loss 0.041729
# batch 5596: loss 0.109511
# batch 5597: loss 0.010007
# batch 5598: loss 0.043646
# batch 5599: loss 0.240900
# batch 5600: loss 0.048786
# batch 5601: loss 0.113203
# batch 5602: loss 0.023709
# batch 5603: loss 0.019192
# batch 5604: loss 0.013117
# batch 5605: loss 0.020430
# batch 5606: loss 0.200775
# batch 5607: loss 0.026389
# batch 5608: loss 0.037787
# batch 5609: loss 0.027021
# batch 5610: loss 0.007429
# batch 5611: loss 0.024867
# batch 5612: loss 0.050489
# batch 5613: loss 0.059572
# batch 5614: loss 0.019134
# batch 5615: loss 0.027261
# batch 5616: loss 0.050115
# batch 5617: loss 0.018646
# batch 5618: loss 0.179330
# batch 5619: loss 0.094090
# batch 5620: loss 0.220941
# batch 5621: loss 0.152054
# batch 5622: loss 0.086886
# batch 5623: loss 0.012874
# batch 5624: loss 0.035618
# batch 5625: loss 0.023769
# batch 5626: loss 0.131874
# batch 5627: loss 0.093888
# batch 5628: loss 0.037928
# batch 5629: loss 0.008368
# batch 5630: loss 0.023929
# batch 5631: loss 0.010834
# batch 5632: loss 0.005567
# batch 5633: loss 0.041095
# batch 5634: loss 0.002453
# batch 5635: loss 0.018319
# batch 5636: loss 0.011850
# batch 5637: loss 0.034744
# batch 5638: loss 0.136965
# batch 5639: loss 0.003022
# batch 5640: loss 0.019803
# batch 5641: loss 0.055519
# batch 5642: loss 0.012906
# batch 5643: loss 0.009666
# batch 5644: loss 0.112592
# batch 5645: loss 0.115190
# batch 5646: loss 0.029858
# batch 5647: loss 0.067056
# batch 5648: loss 0.119700
# batch 5649: loss 0.075249
# batch 5650: loss 0.013468
# batch 5651: loss 0.005068
# batch 5652: loss 0.104326
# batch 5653: loss 0.048747
# batch 5654: loss 0.075851
# batch 5655: loss 0.027152
# batch 5656: loss 0.005012
# batch 5657: loss 0.082402
# batch 5658: loss 0.056782
# batch 5659: loss 0.143960
# batch 5660: loss 0.098807
# batch 5661: loss 0.009298
# batch 5662: loss 0.090146
# batch 5663: loss 0.057926
# batch 5664: loss 0.098304
# batch 5665: loss 0.045624
# batch 5666: loss 0.149057
# batch 5667: loss 0.005719
# batch 5668: loss 0.046249
# batch 5669: loss 0.043146
# batch 5670: loss 0.114397
# batch 5671: loss 0.113520
# batch 5672: loss 0.207682
# batch 5673: loss 0.049044
# batch 5674: loss 0.099974
# batch 5675: loss 0.058272
# batch 5676: loss 0.335037
# batch 5677: loss 0.123981
# batch 5678: loss 0.009046
# batch 5679: loss 0.063479
# batch 5680: loss 0.022511
# batch 5681: loss 0.018431
# batch 5682: loss 0.080396
# batch 5683: loss 0.010981
# batch 5684: loss 0.014585
# batch 5685: loss 0.002553
# batch 5686: loss 0.014134
# batch 5687: loss 0.096683
# batch 5688: loss 0.005744
# batch 5689: loss 0.008715
# batch 5690: loss 0.048590
# batch 5691: loss 0.013702
# batch 5692: loss 0.003523
# batch 5693: loss 0.018090
# batch 5694: loss 0.028421
# batch 5695: loss 0.072894
# batch 5696: loss 0.014459
# batch 5697: loss 0.031672
# batch 5698: loss 0.013742
# batch 5699: loss 0.025979
# batch 5700: loss 0.016175
# batch 5701: loss 0.155018
# batch 5702: loss 0.104365
# batch 5703: loss 0.025286
# batch 5704: loss 0.020457
# batch 5705: loss 0.039101
# batch 5706: loss 0.002106
# batch 5707: loss 0.043570
# batch 5708: loss 0.028301
# batch 5709: loss 0.004369
# batch 5710: loss 0.110657
# batch 5711: loss 0.031390
# batch 5712: loss 0.040912
# batch 5713: loss 0.018163
# batch 5714: loss 0.020934
# batch 5715: loss 0.025076
# batch 5716: loss 0.059298
# batch 5717: loss 0.048643
# batch 5718: loss 0.036588
# batch 5719: loss 0.010772
# batch 5720: loss 0.043102
# batch 5721: loss 0.011835
# batch 5722: loss 0.107466
# batch 5723: loss 0.003692
# batch 5724: loss 0.016259
# batch 5725: loss 0.025824
# batch 5726: loss 0.075175
# batch 5727: loss 0.065938
# batch 5728: loss 0.072793
# batch 5729: loss 0.008174
# batch 5730: loss 0.006485
# batch 5731: loss 0.034207
# batch 5732: loss 0.040818
# batch 5733: loss 0.067931
# batch 5734: loss 0.036960
# batch 5735: loss 0.013094
# batch 5736: loss 0.058529
# batch 5737: loss 0.008668
# batch 5738: loss 0.015481
# batch 5739: loss 0.047039
# batch 5740: loss 0.007876
# batch 5741: loss 0.044331
# batch 5742: loss 0.013058
# batch 5743: loss 0.083858
# batch 5744: loss 0.032467
# batch 5745: loss 0.021103
# batch 5746: loss 0.116118
# batch 5747: loss 0.019481
# batch 5748: loss 0.015902
# batch 5749: loss 0.032949
# batch 5750: loss 0.329756
# batch 5751: loss 0.033413
# batch 5752: loss 0.069743
# batch 5753: loss 0.014544
# batch 5754: loss 0.155653
# batch 5755: loss 0.007495
# batch 5756: loss 0.070378
# batch 5757: loss 0.059137
# batch 5758: loss 0.015285
# batch 5759: loss 0.010890
# batch 5760: loss 0.046471
# batch 5761: loss 0.045071
# batch 5762: loss 0.021303
# batch 5763: loss 0.018190
# batch 5764: loss 0.019467
# batch 5765: loss 0.049090
# batch 5766: loss 0.064592
# batch 5767: loss 0.019630
# batch 5768: loss 0.082130
# batch 5769: loss 0.011779
# batch 5770: loss 0.264333
# batch 5771: loss 0.034678
# batch 5772: loss 0.013508
# batch 5773: loss 0.170161
# batch 5774: loss 0.053683
# batch 5775: loss 0.003543
# batch 5776: loss 0.065794
# batch 5777: loss 0.020936
# batch 5778: loss 0.073127
# batch 5779: loss 0.178310
# batch 5780: loss 0.071354
# batch 5781: loss 0.005197
# batch 5782: loss 0.015721
# batch 5783: loss 0.069388
# batch 5784: loss 0.119704
# batch 5785: loss 0.121714
# batch 5786: loss 0.007827
# batch 5787: loss 0.123998
# batch 5788: loss 0.130871
# batch 5789: loss 0.048053
# batch 5790: loss 0.028247
# batch 5791: loss 0.213036
# batch 5792: loss 0.032596
# batch 5793: loss 0.005207
# batch 5794: loss 0.015512
# batch 5795: loss 0.148123
# batch 5796: loss 0.005359
# batch 5797: loss 0.099894
# batch 5798: loss 0.116000
# batch 5799: loss 0.113407
# batch 5800: loss 0.184878
# batch 5801: loss 0.028255
# batch 5802: loss 0.047969
# batch 5803: loss 0.057917
# batch 5804: loss 0.060579
# batch 5805: loss 0.063305
# batch 5806: loss 0.011262
# batch 5807: loss 0.035129
# batch 5808: loss 0.031951
# batch 5809: loss 0.043157
# batch 5810: loss 0.146750
# batch 5811: loss 0.036364
# batch 5812: loss 0.008989
# batch 5813: loss 0.013119
# batch 5814: loss 0.020664
# batch 5815: loss 0.016350
# batch 5816: loss 0.030595
# batch 5817: loss 0.084545
# batch 5818: loss 0.120732
# batch 5819: loss 0.210153
# batch 5820: loss 0.079586
# batch 5821: loss 0.020172
# batch 5822: loss 0.081976
# batch 5823: loss 0.005131
# batch 5824: loss 0.004287
# batch 5825: loss 0.178796
# batch 5826: loss 0.008886
# batch 5827: loss 0.068978
# batch 5828: loss 0.062047
# batch 5829: loss 0.009128
# batch 5830: loss 0.014626
# batch 5831: loss 0.028632
# batch 5832: loss 0.018101
# batch 5833: loss 0.039173
# batch 5834: loss 0.013639
# batch 5835: loss 0.033535
# batch 5836: loss 0.007481
# batch 5837: loss 0.027875
# batch 5838: loss 0.016112
# batch 5839: loss 0.087385
# batch 5840: loss 0.036046
# batch 5841: loss 0.007171
# batch 5842: loss 0.063358
# batch 5843: loss 0.007015
# batch 5844: loss 0.018661
# batch 5845: loss 0.084802
# batch 5846: loss 0.007116
# batch 5847: loss 0.190378
# batch 5848: loss 0.041827
# batch 5849: loss 0.133543
# batch 5850: loss 0.011922
# batch 5851: loss 0.141408
# batch 5852: loss 0.016102
# batch 5853: loss 0.090225
# batch 5854: loss 0.005322
# batch 5855: loss 0.096879
# batch 5856: loss 0.056332
# batch 5857: loss 0.074782
# batch 5858: loss 0.098217
# batch 5859: loss 0.014886
# batch 5860: loss 0.153768
# batch 5861: loss 0.020263
# batch 5862: loss 0.112665
# batch 5863: loss 0.006691
# batch 5864: loss 0.016759
# batch 5865: loss 0.072610
# batch 5866: loss 0.048896
# batch 5867: loss 0.019666
# batch 5868: loss 0.051902
# batch 5869: loss 0.006643
# batch 5870: loss 0.016186
# batch 5871: loss 0.006290
# batch 5872: loss 0.073051
# batch 5873: loss 0.201164
# batch 5874: loss 0.020677
# batch 5875: loss 0.011953
# batch 5876: loss 0.328681
# batch 5877: loss 0.029870
# batch 5878: loss 0.140267
# batch 5879: loss 0.024361
# batch 5880: loss 0.006757
# batch 5881: loss 0.112802
# batch 5882: loss 0.040756
# batch 5883: loss 0.039730
# batch 5884: loss 0.004506
# batch 5885: loss 0.130887
# batch 5886: loss 0.008460
# batch 5887: loss 0.052436
# batch 5888: loss 0.028639
# batch 5889: loss 0.041140
# batch 5890: loss 0.183324
# batch 5891: loss 0.124040
# batch 5892: loss 0.074699
# batch 5893: loss 0.033550
# batch 5894: loss 0.107516
# batch 5895: loss 0.122108
# batch 5896: loss 0.057650
# batch 5897: loss 0.098478
# batch 5898: loss 0.003593
# batch 5899: loss 0.007806
# batch 5900: loss 0.004280
# batch 5901: loss 0.051036
# batch 5902: loss 0.045999
# batch 5903: loss 0.071791
# batch 5904: loss 0.038389
# batch 5905: loss 0.052293
# batch 5906: loss 0.086660
# batch 5907: loss 0.035598
# batch 5908: loss 0.047264
# batch 5909: loss 0.007483
# batch 5910: loss 0.074310
# batch 5911: loss 0.018653
# batch 5912: loss 0.043579
# batch 5913: loss 0.025862
# batch 5914: loss 0.072840
# batch 5915: loss 0.157667
# batch 5916: loss 0.023609
# batch 5917: loss 0.009109
# batch 5918: loss 0.011875
# batch 5919: loss 0.028067
# batch 5920: loss 0.136370
# batch 5921: loss 0.014214
# batch 5922: loss 0.037188
# batch 5923: loss 0.028124
# batch 5924: loss 0.111294
# batch 5925: loss 0.032897
# batch 5926: loss 0.017543
# batch 5927: loss 0.075505
# batch 5928: loss 0.013175
# batch 5929: loss 0.202413
# batch 5930: loss 0.082090
# batch 5931: loss 0.081567
# batch 5932: loss 0.199769
# batch 5933: loss 0.007081
# batch 5934: loss 0.163102
# batch 5935: loss 0.045611
# batch 5936: loss 0.042640
# batch 5937: loss 0.024153
# batch 5938: loss 0.070341
# batch 5939: loss 0.086097
# batch 5940: loss 0.005815
# batch 5941: loss 0.113243
# batch 5942: loss 0.012460
# batch 5943: loss 0.036965
# batch 5944: loss 0.003460
# batch 5945: loss 0.037744
# batch 5946: loss 0.023315
# batch 5947: loss 0.035052
# batch 5948: loss 0.134034
# batch 5949: loss 0.043132
# batch 5950: loss 0.065963
# batch 5951: loss 0.108018
# batch 5952: loss 0.007429
# batch 5953: loss 0.009686
# batch 5954: loss 0.065684
# batch 5955: loss 0.005439
# batch 5956: loss 0.003445
# batch 5957: loss 0.043943
# batch 5958: loss 0.050922
# batch 5959: loss 0.122284
# batch 5960: loss 0.051185
# batch 5961: loss 0.030036
# batch 5962: loss 0.025948
# batch 5963: loss 0.036303
# batch 5964: loss 0.228115
# batch 5965: loss 0.144236
# batch 5966: loss 0.005964
# batch 5967: loss 0.015557
# batch 5968: loss 0.034966
# batch 5969: loss 0.005651
# batch 5970: loss 0.005530
# batch 5971: loss 0.052053
# batch 5972: loss 0.006516
# batch 5973: loss 0.066727
# batch 5974: loss 0.042737
# batch 5975: loss 0.039108
# batch 5976: loss 0.060408
# batch 5977: loss 0.051925
# batch 5978: loss 0.025407
# batch 5979: loss 0.030410
# batch 5980: loss 0.002609
# batch 5981: loss 0.013935
# batch 5982: loss 0.028614
# batch 5983: loss 0.026473
# batch 5984: loss 0.054668
# batch 5985: loss 0.079150
# batch 5986: loss 0.045903
# batch 5987: loss 0.025659
# batch 5988: loss 0.040350
# batch 5989: loss 0.003346
# batch 5990: loss 0.028195
# batch 5991: loss 0.053553
# batch 5992: loss 0.088797
# batch 5993: loss 0.111445
# batch 5994: loss 0.034853
# batch 5995: loss 0.020907
# batch 5996: loss 0.092721
# batch 5997: loss 0.066151
# batch 5998: loss 0.062640
# batch 5999: loss 0.026997
