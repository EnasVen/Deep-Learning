# %% [markdown]
# # Skip-Gram(TensorFlow版本)
# 由於Bag of Words對於相似的字詞並沒有產生關聯性，且字向量的維度非常高(多為稀疏)，浪費儲存空間。
# 因此相似的定義可以從上下文著手，例如:兩個字詞A,B前後的字詞常常相同，則此A,B兩詞的意義可能相近。
#
# Skip-Gram 透過指定window-size=n蒐集training sample，將句子內的字詞前後n範圍內的字詞與指定字詞組成tuple。
# 例如: (the  , quick) , (the , brown) , (quick , the) , (quick , brown) , (quick , fox) ...
#
# 收集好測試樣本後，將每個字詞做one-hot encoding。
# 接著建構DNN，中間的隱藏層只有1層，且不放入激活函數，目的是要保持字詞的線性關係。
#
# 訓練完的類神經網路會得到一組V*N的參數矩陣，此參數稱為lookup table。
# 其中V為詞彙量，N為隱藏層內的神經元數量。
#
# 所以如果我們想得到每一個詞彙所代表的向量，我們就把它的one-hot編碼拿來與lookup table做矩陣相乘，所得結果即為詞彙所代表的向量!!
# i.e. v'_(V by 1) * W_(V by N)
#
# skip-gram在訓練網路時，如果loss用cross-entropy，則softmax計算量會很大!
# 所以他採用部分更新權重(Negative Sampling)的方式:
# 這個負採樣可以將隱藏層輸出的向量與結果label data比對，只留下結果非0的元素位置，剩下都是0的位置隨機選取N個保留。
# 這樣可以減少系統運算的負荷，例如: [0.2,0.5,0.1,-0.3,....] => [0,1,0]原始10000維向量只需要保留3維即可。
#
# 權重更新的時候也只需take care不同的部分就好!  也就是 [0.2,-0.1,0.2] <=> [0,1,0]

# %%
import tensorflow as tf
from tensorflow import keras
from utils import process_w2v_data     
from visual import show_w2v_word_embedding  

corpus = [
    # numbers
    "5 2 4 8 6 2 3 6 4",
    "4 8 5 6 9 5 5 6",
    "1 1 5 2 3 3 8",
    "3 6 9 6 8 7 4 6 3",
    "8 9 9 6 1 4 3 4",
    "1 0 2 0 2 1 3 3 3 3 3",
    "9 3 3 0 1 4 7 8",
    "9 9 8 5 6 7 1 2 3 0 1 0",

    # alphabets, expecting that 9 is close to letters
    "a t g q e h 9 u f",
    "e q y u o i p s",
    "q o 9 p l k j o k k o p",
    "h g y i u t t a e q",
    "i k d q r e 9 e a d",
    "o p d g 9 s a f g a",
    "i u y g h k l a s w",
    "o l u y a o g f s",
    "o p i u y g d a s j d l",
    "u k i l o 9 l j s",
    "y g i s h k j l f r f",
    "i o h n 9 9 d 9 f a 9",
]


class SkipGram(keras.Model):
    def __init__(self, v_dim, emb_dim):
        super().__init__()
        self.v_dim = v_dim
        self.embeddings = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,       # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.1),
        )

        # noise-contrastive estimation
        self.nce_w = self.add_weight(
            name="nce_w", shape=[v_dim, emb_dim],
            initializer=keras.initializers.TruncatedNormal(0., 0.1))  # [n_vocab, emb_dim]
        self.nce_b = self.add_weight(
            name="nce_b", shape=(v_dim,),
            initializer=keras.initializers.Constant(0.1))  # [n_vocab, ]

        self.opt = keras.optimizers.Adam(0.01)

    def call(self, x, training=None, mask=None):
        # x.shape = [n, ]
        o = self.embeddings(x)      # [n, emb_dim]
        return o

    # negative sampling: take one positive label and num_sampled negative labels to compute the loss
    # in order to reduce the computation of full softmax
    def loss(self, x, y, training=None):
        embedded = self.call(x, training)
        return tf.reduce_mean(
            tf.nn.nce_loss(
                weights=self.nce_w, biases=self.nce_b, labels=tf.expand_dims(y, axis=1),
                inputs=embedded, num_sampled=5, num_classes=self.v_dim))

    def step(self, x, y):
        with tf.GradientTape() as tape:
            loss = self.loss(x, y, True)
            grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss.numpy()


def train(model, data):
    for t in range(2500):
        bx, by = data.sample(8)
        loss = model.step(bx, by)
        if t % 200 == 0:
            print("step: {} | loss: {}".format(t, loss))


if __name__ == "__main__":
    # process_w2v_data為util.py裡面的函數，會產生v2i和i2v兩個向量
    d = process_w2v_data(corpus, skip_window=2, method="skip_gram")
    print(d.i2v[16])
    print(d.i2v[14])
    print(d.i2v[9])
    print(d.i2v[12])
    m = SkipGram(d.num_word, 2)
    train(m, d)

    # plotting
    show_w2v_word_embedding(m, d, "./visual/results/skipgram.png")
# Out:
# all vocabularies sorted from more frequent to less frequent:
#  ['9' '3' 'o' '6' 'a' '1' 'i' 'g' 's' '4' 'l' 'k' '8' 'u' '2' 'd' '5' 'y'
#  'f' 'e' 'h' 'p' 'q' '0' 'j' '7' 't' 'r' 'w' 'n']
# 5 example pairs:
#  [[16 14]
#  [16  9]
#  [14 16]
#  [14  9]
#  [14 12]]
# 5
# 2
# 4
# 8
# step: 0 | loss: 10.700535774230957
# step: 200 | loss: 2.4407119750976562
# step: 400 | loss: 2.497330665588379
# step: 600 | loss: 2.925737142562866
# step: 800 | loss: 2.5977611541748047
# step: 1000 | loss: 2.6577446460723877
# step: 1200 | loss: 2.5318217277526855
# step: 1400 | loss: 2.425910472869873
# step: 1600 | loss: 2.0300350189208984
# step: 1800 | loss: 2.980332374572754
# step: 2000 | loss: 1.9168641567230225
# step: 2200 | loss: 2.325024127960205
# step: 2400 | loss: 2.557227611541748

# %%
from __future__ import division, print_function, absolute_import
import collections
import os
import random
import urllib
import zipfile
from urllib.request import urlretrieve
import numpy as np
import tensorflow as tf
tf.compat.v1.reset_default_graph


learning_rate = 0.1
batch_size = 128
num_steps = 1000
display_step = 100
eval_step = 50


eval_words = ['five', 'of', 'going', 'hardware', 'american', 'britain']


embedding_size = 128 
max_vocabulary_size = 50000 
min_occurrence = 10  # 詞彙必須最少發生10次
skip_window = 1  # n-gram window
num_skips = 2  # 輸出層保留觀察的0元素
num_sampled = 64  # 隱藏層神經元個數N

# %%
url = 'http://mattmahoney.net/dc/text8.zip'
data_path = 'text8.zip'
# if not os.path.exists(data_path):
#     print("Downloading the dataset... (It may take some time)")
#     filename, _ = urllib.request.urlretrieve(url, data_path)
#     print("Done!")

with zipfile.ZipFile(data_path) as f:
    text_words = f.read(f.namelist()[0]).decode('utf8').lower().split()
    
print(text_words[:5])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term']

# %%
count = [('UNK', -1)]

count.extend(collections.Counter(text_words).most_common(max_vocabulary_size - 1))

for i in range(len(count) - 1, -1, -1):
    if count[i][1] < min_occurrence:
        count.pop(i)
    else:
        break

vocabulary_size = len(count)

word2id = dict()
for i, (word, _) in enumerate(count):
    word2id[word] = i

data = list()
unk_count = 0
for word in text_words:

    index = word2id.get(word, 0)
    if index == 0:
        unk_count += 1
    data.append(index)
count[0] = ('UNK', unk_count)
id2word = dict(zip(word2id.values(), word2id.keys()))

print("Words count:", len(text_words))
print("Unique words:", len(set(text_words)))
print("Vocabulary size:", vocabulary_size)
print("Most common words:", count[:10])
# Out:
# Words count: 17005207
# Unique words: 253854
# Vocabulary size: 47135
# Most common words: [('UNK', 444176), ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]

# %%
data_index = 0

# 將每一個批次的訓練樣本回傳出來
def next_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

    span = 2 * skip_window + 1
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            buffer.extend(data[0:span])
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1

    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

# %%
with tf.device('/cpu:0'):

    embedding = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))

    nce_weights = tf.Variable(tf.random.normal([vocabulary_size, embedding_size]))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

def get_embedding(x):
    with tf.device('/cpu:0'):

        x_embed = tf.nn.embedding_lookup(embedding, x)
        return x_embed

def nce_loss(x_embed, y):
    with tf.device('/cpu:0'):

        y = tf.cast(y, tf.int64)
        loss = tf.reduce_mean(
            tf.nn.nce_loss(weights=nce_weights,
                           biases=nce_biases,
                           labels=y,
                           inputs=x_embed,
                           num_sampled=num_sampled,
                           num_classes=vocabulary_size))
        return loss

# 评估
def evaluate(x_embed):
    with tf.device('/cpu:0'):

        x_embed = tf.cast(x_embed, tf.float32)
        x_embed_norm = x_embed / tf.sqrt(tf.reduce_sum(tf.square(x_embed)))
        embedding_norm = embedding / tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True), tf.float32)
        cosine_sim_op = tf.matmul(x_embed_norm, embedding_norm, transpose_b=True) # cos相似度
        return cosine_sim_op


optimizer = tf.optimizers.SGD(learning_rate)

# %%
def run_optimization(x, y):
    with tf.device('/cpu:0'):

        with tf.GradientTape() as g:
            emb = get_embedding(x)
            loss = nce_loss(emb, y)

        gradients = g.gradient(loss, [embedding, nce_weights, nce_biases])

        optimizer.apply_gradients(zip(gradients, [embedding, nce_weights, nce_biases]))

# %%
# print(word2id)
x_test = np.array([word2id[str(w)] for w in eval_words])

for step in range(1, num_steps + 1):
    batch_x, batch_y = next_batch(batch_size, num_skips, skip_window)
    run_optimization(batch_x, batch_y)

    if step % display_step == 0 or step == 1:
        loss = nce_loss(get_embedding(batch_x), batch_y)
        print("step: %i, loss: %f" % (step, loss))

    if step % eval_step == 0 or step == 1:
        print("Evaluation...")
        sim = evaluate(get_embedding(x_test)).numpy()
        for i in range(len(eval_words)):
            top_k = 8 
            nearest = (-sim[i, :]).argsort()[1:top_k + 1]
            log_str = '"%s" nearest neighbors:' % eval_words[i]
            for k in range(top_k):
                log_str = '%s %s,' % (log_str, id2word[nearest[k]])
            print(log_str)
# Out:
# step: 1, loss: 453.815674
# Evaluation...
# "five" nearest neighbors: believers, librarian, ended, rennet, twentieth, broadbent, complements, hwang,
# "of" nearest neighbors: riddler, decommissioned, gamelan, schema, gary, plectrum, flown, discharges,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, jost, sinai, unabridged, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, trombonist, electorates, medina,
# Evaluation...
# "five" nearest neighbors: believers, ended, rennet, librarian, broadbent, twentieth, complements, conflated,
# "of" nearest neighbors: discharges, schema, decommissioned, riddler, grabs, gary, appleton, whitehead,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, sinai, jost, unabridged, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, trombonist, electorates, medina,
# step: 100, loss: 376.371765
# Evaluation...
# "five" nearest neighbors: believers, ended, rennet, librarian, broadbent, twentieth, conflated, complements,
# "of" nearest neighbors: the, schema, discharges, whitehead, and, appleton, riddler, shifted,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, sinai, jost, unabridged, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, trombonist, electorates, medina,
# Evaluation...
# "five" nearest neighbors: believers, ended, librarian, broadbent, rennet, twentieth, conflated, complements,
# "of" nearest neighbors: the, and, UNK, discharges, supersymmetric, schema, one, whitehead,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, sinai, unabridged, jost, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, trombonist, electorates, medina,
# step: 200, loss: 359.640503
# Evaluation...
# "five" nearest neighbors: believers, librarian, ended, rennet, twentieth, broadbent, conflated, complements,
# "of" nearest neighbors: the, and, a, one, UNK, in, to, consolidating,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, sinai, unabridged, jost, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, trombonist, electorates, medina,
# Evaluation...
# "five" nearest neighbors: believers, twentieth, librarian, ended, rennet, broadbent, conflated, issachar,
# "of" nearest neighbors: the, and, to, in, one, UNK, a, zero,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, sinai, unabridged, jost, evanston, forging,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, electorates, trombonist, termination,
# step: 300, loss: 350.542694
# Evaluation...
# "five" nearest neighbors: believers, librarian, ended, twentieth, rennet, broadbent, origins, sedatives,
# "of" nearest neighbors: the, and, in, a, UNK, to, one, zero,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, evanston, sinai, jost, deterred,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, electorates, trombonist, termination,
# Evaluation...
# "five" nearest neighbors: believers, librarian, twentieth, broadbent, ended, origins, barking, sedatives,
# "of" nearest neighbors: the, and, in, to, UNK, one, a, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, evanston, sinai, jost, deterred,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, electorates, trombonist, termination,
# step: 400, loss: 345.279724
# Evaluation...
# "five" nearest neighbors: believers, origins, ended, librarian, montag, broadbent, rennet, issachar,
# "of" nearest neighbors: the, and, in, to, one, a, UNK, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, evanston, sinai, jost, deterred,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, electorates, trombonist, see,
# Evaluation...
# "five" nearest neighbors: believers, ended, origins, librarian, montag, rennet, broadbent, issachar,
# "of" nearest neighbors: the, and, in, to, a, one, UNK, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, evanston, sinai, jost, deterred,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, see, trombonist, electorates,
# step: 500, loss: 269.484741
# Evaluation...
# "five" nearest neighbors: believers, origins, issachar, ended, montag, fox, librarian, broadbent,
# "of" nearest neighbors: the, and, in, to, a, one, UNK, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, collapsed, evanston, hawthorn,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, see, trombonist, electorates,
# Evaluation...
# "five" nearest neighbors: believers, issachar, ended, montag, origins, one, broadbent, cdu,
# "of" nearest neighbors: the, and, in, to, a, UNK, one, lincoln,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, collapsed, jost, hawthorn,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, see, trombonist, electorates,
# step: 600, loss: 309.588196
# Evaluation...
# "five" nearest neighbors: believers, the, in, one, issachar, s, ended, is,
# "of" nearest neighbors: the, and, in, to, a, UNK, one, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, same, contrasting, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, collapsed, jost, hawthorn,
# "britain" nearest neighbors: world, fleets, saa, kops, disembarked, see, trombonist, electorates,
# Evaluation...
# "five" nearest neighbors: one, in, s, the, of, UNK, is, and,
# "of" nearest neighbors: the, and, in, to, a, UNK, one, is,
# "going" nearest neighbors: pontiac, kurgan, branded, papuan, contrasting, same, flourishes, megabits,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, jost, hawthorn, diocletian,
# "britain" nearest neighbors: world, fleets, saa, kops, see, disembarked, trombonist, electorates,
# step: 700, loss: 292.241089
# Evaluation...
# "five" nearest neighbors: one, in, s, the, of, UNK, and, believers,
# "of" nearest neighbors: the, and, in, to, a, one, UNK, is,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, same, contrasting, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, jost, hawthorn, diocletian,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, trombonist, electorates,
# Evaluation...
# "five" nearest neighbors: s, UNK, and, in, one, the, of, a,
# "of" nearest neighbors: the, and, in, a, to, UNK, one, is,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, same, contrasting, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, jost, diocletian, hawthorn,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, on, trombonist,
# step: 800, loss: 252.679459
# Evaluation...
# "five" nearest neighbors: s, of, one, and, the, UNK, in, a,
# "of" nearest neighbors: the, and, in, a, UNK, to, is, one,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, same, contrasting, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, hills,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, diocletian, jost, hawthorn,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, trombonist, electorates,
# Evaluation...
# "five" nearest neighbors: of, s, and, the, one, nine, in, to,
# "of" nearest neighbors: the, and, in, to, a, UNK, one, is,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, same, contrasting, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, hawthorn, diocletian, cheetah,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, on, trombonist,
# step: 900, loss: 270.868896
# Evaluation...
# "five" nearest neighbors: s, and, of, the, in, UNK, to, nine,
# "of" nearest neighbors: the, and, in, to, a, is, UNK, one,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, same, contrasting, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, hawthorn, diocletian, cheetah,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, trombonist, electorates,
# Evaluation...
# "five" nearest neighbors: s, and, in, of, UNK, to, nine, a,
# "of" nearest neighbors: the, and, a, in, to, is, UNK, one,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, contrasting, same, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, hawthorn, diocletian, cheetah,
# "britain" nearest neighbors: world, fleets, saa, see, kops, disembarked, trombonist, one,
# step: 1000, loss: 237.788879
# Evaluation...
# "five" nearest neighbors: s, in, and, UNK, to, a, is, of,
# "of" nearest neighbors: the, in, and, is, a, to, UNK, one,
# "going" nearest neighbors: pontiac, branded, kurgan, papuan, contrasting, same, flourishes, reds,
# "hardware" nearest neighbors: dispose, flame, equivalently, paralleled, zahn, bedrock, maintenance, controversial,
# "american" nearest neighbors: formalize, altos, thirteen, unabridged, sinai, cheetah, jost, hawthorn,
# "britain" nearest neighbors: world, of, the, fleets, one, saa, see, kops,

# %%
from sklearn.manifold import TSNE
from matplotlib import pylab

num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(embedding[1:num_points+1, :])

def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                        ha='right', va='bottom')
    pylab.show()

words = [id2word[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# C:\Users\Student\anaconda3\envs\AI_Course\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# C:\Users\Student\anaconda3\envs\AI_Course\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
