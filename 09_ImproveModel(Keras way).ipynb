# %% [markdown]
# # 平均損失函數
# reduce_mean(loss) 可以讓每一個batch訓練後output出當前batch的loss

# %%
import numpy as np
import tensorflow as tf
tf.compat.v1.reset_default_graph()
class MNISTLoader():
    def __init__(self):
        mnist = tf.keras.datasets.mnist
        (self.train_data, self.train_label), (self.test_data, self.test_label) = mnist.load_data()

        self.train_data = np.expand_dims(self.train_data.astype(np.float32) / 255.0, axis=-1)      # [60000, 28, 28, 1]
        self.test_data = np.expand_dims(self.test_data.astype(np.float32) / 255.0, axis=-1)        # [10000, 28, 28, 1]
        self.train_label = self.train_label.astype(np.int32)    # [60000]
        self.test_label = self.test_label.astype(np.int32)      # [10000]
        self.num_train_data, self.num_test_data = self.train_data.shape[0], self.test_data.shape[0]

    def get_batch(self, batch_size):

        index = np.random.randint(0, self.num_train_data, batch_size)
        return self.train_data[index, :], self.train_label[index]
    
class MLP(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.flatten = tf.keras.layers.Flatten()    
        self.dense1 = tf.keras.layers.Dense(units=100, activation=tf.nn.relu)
        self.dense2 = tf.keras.layers.Dense(units=10)

    def call(self, inputs):         # [batch_size, 28, 28, 1]
        x = self.flatten(inputs)    # [batch_size, 784]
        x = self.dense1(x)          # [batch_size, 100]
        x = self.dense2(x)          # [batch_size, 10]
        output = tf.nn.softmax(x)
        return output

num_epochs = 5
batch_size = 5
learning_rate = 0.001

model = MLP()
data_loader = MNISTLoader()

num_batches = int(data_loader.num_train_data // batch_size * num_epochs)

X, y = data_loader.get_batch(batch_size)
with tf.GradientTape() as tape:
    y_pred = model(X)
    loss = tf.keras.losses.sparse_categorical_crossentropy(y_true=y, y_pred=y_pred)
    # 計算當前 batch loss
    loss = tf.reduce_mean(loss)
    print(loss)
# Out:
# tf.Tensor(2.621033, shape=(), dtype=float32)

# %% [markdown]
# # 優化神經網路(keras版本)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.compat.v1.reset_default_graph()

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape([x_train.shape[0], -1])
x_test = x_test.reshape([x_test.shape[0], -1])
print(x_train.shape, ' ', y_train.shape)
print(x_test.shape, ' ', y_test.shape)
# Out:
# (60000, 784)   (60000,)
# (10000, 784)   (10000,)

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(784,)), # 784 * 64 + 64
    layers.Dense(64, activation='relu'), # 64*64 + 64
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax') #64*10 + 10
])


#keras.optimizers.Adagrad(learning_rate=0.01)
#keras.optimizers.Adam(learning_rate=0.01)
#keras.optimizers.RMSprop(learning_rate=0.01)

# provide labels as one_hot representation => tf.keras.losses.CategoricalCrossentropy
# provide labels as integers => tf.keras.losses.SparseCategoricalCrossentropy 
model.compile(optimizer=keras.optimizers.Adam(),
             loss=keras.losses.SparseCategoricalCrossentropy(),
             metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                650
# =================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
#history = model.fit(x_train, y_train, batch_size=256, epochs=100, validation_split=0.3, verbose=2)
# verbose 代表呈現資訊詳細度 2最詳細 0最簡略 只可選擇 0/1/2來操作
history = model.fit(x_train, y_train, batch_size=256, epochs=100, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/100
# 235/235 - 0s - loss: 2.2645 - accuracy: 0.7448 - val_loss: 0.5907 - val_accuracy: 0.8683
# Epoch 2/100
# 235/235 - 0s - loss: 0.4284 - accuracy: 0.8902 - val_loss: 0.3686 - val_accuracy: 0.9031
# Epoch 3/100
# 235/235 - 0s - loss: 0.2889 - accuracy: 0.9209 - val_loss: 0.2874 - val_accuracy: 0.9224
# Epoch 4/100
# 235/235 - 0s - loss: 0.2202 - accuracy: 0.9378 - val_loss: 0.2524 - val_accuracy: 0.9305
# Epoch 5/100
# 235/235 - 0s - loss: 0.1808 - accuracy: 0.9466 - val_loss: 0.2347 - val_accuracy: 0.9372
# Epoch 6/100
# 235/235 - 0s - loss: 0.1509 - accuracy: 0.9555 - val_loss: 0.2102 - val_accuracy: 0.9448
# Epoch 7/100
# 235/235 - 0s - loss: 0.1315 - accuracy: 0.9610 - val_loss: 0.2035 - val_accuracy: 0.9449
# Epoch 8/100
# 235/235 - 0s - loss: 0.1191 - accuracy: 0.9637 - val_loss: 0.2043 - val_accuracy: 0.9438
# Epoch 9/100
# 235/235 - 0s - loss: 0.1064 - accuracy: 0.9675 - val_loss: 0.1997 - val_accuracy: 0.9498
# Epoch 10/100
# 235/235 - 0s - loss: 0.1004 - accuracy: 0.9699 - val_loss: 0.1969 - val_accuracy: 0.9495
# Epoch 11/100
# 235/235 - 0s - loss: 0.0895 - accuracy: 0.9722 - val_loss: 0.2083 - val_accuracy: 0.9479
# Epoch 12/100
# 235/235 - 0s - loss: 0.0832 - accuracy: 0.9743 - val_loss: 0.1805 - val_accuracy: 0.9538
# Epoch 13/100
# 235/235 - 0s - loss: 0.0786 - accuracy: 0.9756 - val_loss: 0.1755 - val_accuracy: 0.9585
# Epoch 14/100
# 235/235 - 0s - loss: 0.0730 - accuracy: 0.9774 - val_loss: 0.1797 - val_accuracy: 0.9557
# Epoch 15/100
# 235/235 - 0s - loss: 0.0687 - accuracy: 0.9783 - val_loss: 0.1868 - val_accuracy: 0.9587
# Epoch 16/100
# 235/235 - 0s - loss: 0.0677 - accuracy: 0.9786 - val_loss: 0.1851 - val_accuracy: 0.9582
# Epoch 17/100
# 235/235 - 0s - loss: 0.0623 - accuracy: 0.9802 - val_loss: 0.1949 - val_accuracy: 0.9591
# Epoch 18/100
# 235/235 - 0s - loss: 0.0647 - accuracy: 0.9795 - val_loss: 0.1931 - val_accuracy: 0.9588
# Epoch 19/100
# 235/235 - 0s - loss: 0.0597 - accuracy: 0.9812 - val_loss: 0.1854 - val_accuracy: 0.9580
# Epoch 20/100
# 235/235 - 0s - loss: 0.0552 - accuracy: 0.9820 - val_loss: 0.1798 - val_accuracy: 0.9621
# Epoch 21/100
# 235/235 - 0s - loss: 0.0505 - accuracy: 0.9836 - val_loss: 0.2123 - val_accuracy: 0.9573
# Epoch 22/100
# 235/235 - 0s - loss: 0.0514 - accuracy: 0.9836 - val_loss: 0.2069 - val_accuracy: 0.9605
# Epoch 23/100
# 235/235 - 0s - loss: 0.0497 - accuracy: 0.9849 - val_loss: 0.2012 - val_accuracy: 0.9604
# Epoch 24/100
# 235/235 - 0s - loss: 0.0521 - accuracy: 0.9839 - val_loss: 0.2118 - val_accuracy: 0.9611
# Epoch 25/100
# 235/235 - 0s - loss: 0.0508 - accuracy: 0.9835 - val_loss: 0.1682 - val_accuracy: 0.9650
# Epoch 26/100
# 235/235 - 0s - loss: 0.0453 - accuracy: 0.9858 - val_loss: 0.2353 - val_accuracy: 0.9615
# Epoch 27/100
# 235/235 - 0s - loss: 0.0382 - accuracy: 0.9879 - val_loss: 0.2377 - val_accuracy: 0.9624
# Epoch 28/100
# 235/235 - 0s - loss: 0.0529 - accuracy: 0.9840 - val_loss: 0.2216 - val_accuracy: 0.9608
# Epoch 29/100
# 235/235 - 0s - loss: 0.0392 - accuracy: 0.9878 - val_loss: 0.2057 - val_accuracy: 0.9651
# Epoch 30/100
# 235/235 - 0s - loss: 0.0329 - accuracy: 0.9893 - val_loss: 0.1986 - val_accuracy: 0.9644
# Epoch 31/100
# 235/235 - 0s - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.1991 - val_accuracy: 0.9623
# Epoch 32/100
# 235/235 - 0s - loss: 0.0363 - accuracy: 0.9884 - val_loss: 0.2201 - val_accuracy: 0.9624
# Epoch 33/100
# 235/235 - 0s - loss: 0.0406 - accuracy: 0.9874 - val_loss: 0.2114 - val_accuracy: 0.9626
# Epoch 34/100
# 235/235 - 0s - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.2226 - val_accuracy: 0.9640
# Epoch 35/100
# 235/235 - 0s - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.2113 - val_accuracy: 0.9672
# Epoch 36/100
# 235/235 - 0s - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.2523 - val_accuracy: 0.9610
# Epoch 37/100
# 235/235 - 0s - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.2327 - val_accuracy: 0.9640
# Epoch 38/100
# 235/235 - 0s - loss: 0.0349 - accuracy: 0.9895 - val_loss: 0.2332 - val_accuracy: 0.9669
# Epoch 39/100
# 235/235 - 0s - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.2099 - val_accuracy: 0.9675
# Epoch 40/100
# 235/235 - 0s - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.2331 - val_accuracy: 0.9676
# Epoch 41/100
# 235/235 - 0s - loss: 0.0300 - accuracy: 0.9909 - val_loss: 0.2081 - val_accuracy: 0.9665
# Epoch 42/100
# 235/235 - 0s - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.2325 - val_accuracy: 0.9655
# Epoch 43/100
# 235/235 - 0s - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.2277 - val_accuracy: 0.9681
# Epoch 44/100
# 235/235 - 0s - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.2681 - val_accuracy: 0.9648
# Epoch 45/100
# 235/235 - 0s - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.2531 - val_accuracy: 0.9657
# Epoch 46/100
# 235/235 - 0s - loss: 0.0247 - accuracy: 0.9925 - val_loss: 0.2421 - val_accuracy: 0.9662
# Epoch 47/100
# 235/235 - 0s - loss: 0.0278 - accuracy: 0.9916 - val_loss: 0.2252 - val_accuracy: 0.9661
# Epoch 48/100
# 235/235 - 0s - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.2305 - val_accuracy: 0.9652
# Epoch 49/100
# 235/235 - 0s - loss: 0.0257 - accuracy: 0.9925 - val_loss: 0.2367 - val_accuracy: 0.9684
# Epoch 50/100
# 235/235 - 0s - loss: 0.0231 - accuracy: 0.9931 - val_loss: 0.2380 - val_accuracy: 0.9675
# Epoch 51/100
# 235/235 - 0s - loss: 0.0209 - accuracy: 0.9936 - val_loss: 0.2635 - val_accuracy: 0.9667
# Epoch 52/100
# 235/235 - 0s - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.2381 - val_accuracy: 0.9685
# Epoch 53/100
# 235/235 - 0s - loss: 0.0187 - accuracy: 0.9945 - val_loss: 0.2697 - val_accuracy: 0.9653
# Epoch 54/100
# 235/235 - 0s - loss: 0.0315 - accuracy: 0.9910 - val_loss: 0.3006 - val_accuracy: 0.9628
# Epoch 55/100
# 235/235 - 0s - loss: 0.0297 - accuracy: 0.9917 - val_loss: 0.2557 - val_accuracy: 0.9653
# Epoch 56/100
# 235/235 - 0s - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.2679 - val_accuracy: 0.9671
# Epoch 57/100
# 235/235 - 0s - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.2369 - val_accuracy: 0.9684
# Epoch 58/100
# 235/235 - 0s - loss: 0.0156 - accuracy: 0.9951 - val_loss: 0.2674 - val_accuracy: 0.9679
# Epoch 59/100
# 235/235 - 0s - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.2614 - val_accuracy: 0.9674
# Epoch 60/100
# 235/235 - 0s - loss: 0.0140 - accuracy: 0.9957 - val_loss: 0.2643 - val_accuracy: 0.9684
# Epoch 61/100
# 235/235 - 0s - loss: 0.0216 - accuracy: 0.9938 - val_loss: 0.2313 - val_accuracy: 0.9675
# Epoch 62/100
# 235/235 - 0s - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.2464 - val_accuracy: 0.9697
# Epoch 63/100
# 235/235 - 0s - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.2675 - val_accuracy: 0.9674
# Epoch 64/100
# 235/235 - 0s - loss: 0.0222 - accuracy: 0.9938 - val_loss: 0.2872 - val_accuracy: 0.9652
# Epoch 65/100
# 235/235 - 0s - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.2655 - val_accuracy: 0.9697
# Epoch 66/100
# 235/235 - 0s - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.2762 - val_accuracy: 0.9685
# Epoch 67/100
# 235/235 - 0s - loss: 0.0165 - accuracy: 0.9951 - val_loss: 0.2637 - val_accuracy: 0.9704
# Epoch 68/100
# 235/235 - 0s - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.2881 - val_accuracy: 0.9642
# Epoch 69/100
# 235/235 - 0s - loss: 0.0253 - accuracy: 0.9934 - val_loss: 0.2935 - val_accuracy: 0.9682
# Epoch 70/100
# 235/235 - 0s - loss: 0.0230 - accuracy: 0.9936 - val_loss: 0.2582 - val_accuracy: 0.9684
# Epoch 71/100
# 235/235 - 0s - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.2897 - val_accuracy: 0.9671
# Epoch 72/100
# 235/235 - 0s - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.2586 - val_accuracy: 0.9689
# Epoch 73/100
# 235/235 - 0s - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.2690 - val_accuracy: 0.9693
# Epoch 74/100
# 235/235 - 0s - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.2723 - val_accuracy: 0.9677
# Epoch 75/100
# 235/235 - 0s - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.2915 - val_accuracy: 0.9684
# Epoch 76/100
# 235/235 - 0s - loss: 0.0172 - accuracy: 0.9949 - val_loss: 0.2668 - val_accuracy: 0.9704
# Epoch 77/100
# 235/235 - 0s - loss: 0.0159 - accuracy: 0.9955 - val_loss: 0.2790 - val_accuracy: 0.9705
# Epoch 78/100
# 235/235 - 0s - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.2710 - val_accuracy: 0.9687
# Epoch 79/100
# 235/235 - 0s - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.2843 - val_accuracy: 0.9672
# Epoch 80/100
# 235/235 - 0s - loss: 0.0128 - accuracy: 0.9964 - val_loss: 0.2708 - val_accuracy: 0.9704
# Epoch 81/100
# 235/235 - 0s - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.2684 - val_accuracy: 0.9700
# Epoch 82/100
# 235/235 - 0s - loss: 0.0142 - accuracy: 0.9956 - val_loss: 0.2656 - val_accuracy: 0.9711
# Epoch 83/100
# 235/235 - 0s - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.2915 - val_accuracy: 0.9696
# Epoch 84/100
# 235/235 - 0s - loss: 0.0129 - accuracy: 0.9964 - val_loss: 0.2860 - val_accuracy: 0.9692
# Epoch 85/100
# 235/235 - 0s - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.2697 - val_accuracy: 0.9696
# Epoch 86/100
# 235/235 - 0s - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.2767 - val_accuracy: 0.9718
# Epoch 87/100
# 235/235 - 0s - loss: 0.0178 - accuracy: 0.9950 - val_loss: 0.3067 - val_accuracy: 0.9696
# Epoch 88/100
# 235/235 - 0s - loss: 0.0245 - accuracy: 0.9938 - val_loss: 0.2972 - val_accuracy: 0.9706
# Epoch 89/100
# 235/235 - 0s - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.3310 - val_accuracy: 0.9691
# Epoch 90/100
# 235/235 - 0s - loss: 0.0206 - accuracy: 0.9946 - val_loss: 0.2945 - val_accuracy: 0.9690
# Epoch 91/100
# 235/235 - 0s - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.2813 - val_accuracy: 0.9731
# Epoch 92/100
# 235/235 - 0s - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.2902 - val_accuracy: 0.9708
# Epoch 93/100
# 235/235 - 0s - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.2920 - val_accuracy: 0.9706
# Epoch 94/100
# 235/235 - 0s - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.2920 - val_accuracy: 0.9718
# Epoch 95/100
# 235/235 - 0s - loss: 0.0172 - accuracy: 0.9955 - val_loss: 0.3136 - val_accuracy: 0.9697
# Epoch 96/100
# 235/235 - 0s - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.2861 - val_accuracy: 0.9715
# Epoch 97/100
# 235/235 - 0s - loss: 0.0157 - accuracy: 0.9957 - val_loss: 0.3025 - val_accuracy: 0.9713
# Epoch 98/100
# 235/235 - 0s - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.3041 - val_accuracy: 0.9698
# Epoch 99/100
# 235/235 - 0s - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.3045 - val_accuracy: 0.9708
# Epoch 100/100
# 235/235 - 0s - loss: 0.0190 - accuracy: 0.9955 - val_loss: 0.2833 - val_accuracy: 0.9696
